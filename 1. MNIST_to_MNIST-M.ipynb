# %% [markdown]
# # Preparations

# %%
import torch
import torchvision
import os.path

import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

from sklearn import manifold
from math import exp
from torch.autograd import Variable
from my_dataset import MNIST_M
from my_dataset import ST_Dataset

# %matplotlib inline
# %load_ext skip_kernel_extension

# %%
use_gpu = torch.cuda.is_available()
print("use_gpu = " + str(use_gpu))
# Out:
# use_gpu = True

# %% [markdown]
# # Structure
#
# ![MNIST Structure](https://c1.staticflickr.com/1/978/41270649404_41480327ce_o.png)

# %%
import torch.nn as nn
import torch.nn.functional as F

class CNN(nn.Module):
    
    def __init__(self):
        super(CNN, self).__init__()
        self.C1 = nn.Conv2d(3, 32, 5)
        self.C2 = nn.Conv2d(32, 48, 5)
        self.FC1 = nn.Linear(48 * 4 * 4, 100)
        self.FC2 = nn.Linear(100, 100)
        self.FC3 = nn.Linear(100, 10)
        
    def forward(self, x):
        # C1
        x = F.relu(self.C1(x))
        # M1
        x = F.max_pool2d(x, (2, 2))
        # C2
        x = F.relu(self.C2(x))
        # M2
        x = F.max_pool2d(x, (2, 2))
        # x's size is (128, 48, 4, 4)
        # flatten
        x = x.view(-1, 48 * 4 * 4)
        f = x
        # FC1
        x = F.relu(self.FC1(x))
        # FC2
        x = F.relu(self.FC2(x))
        lh = x
        # FC3
        x = self.FC3(x)
        return x, f, lh

# %%
cnn = CNN()
if (use_gpu):
    cnn.cuda()
print(cnn)
# Out:
# CNN(
#   (C1): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#   (C2): Conv2d(32, 48, kernel_size=(5, 5), stride=(1, 1))
#   (FC1): Linear(in_features=768, out_features=100, bias=True)
#   (FC2): Linear(in_features=100, out_features=100, bias=True)
#   (FC3): Linear(in_features=100, out_features=10, bias=True)
# )

# %% [markdown]
# # MNIST Dataset
#
# Load the dataset using $\texttt{torchvision}$.
#
# * Usage of $\texttt{transforms.Normalize(mean, std)}$:<br>
# Assume that the input has $d$ channels, $\texttt{mean}$ should be a tuple of $d$ values, so should $\texttt{std}$. Let $\texttt{mean = (m1, m2, ..., md)}$ and $\texttt{std = (s1, s2, ..., sd)}$. Then the transform does $$\texttt{input[channel] = (input[channel] - mean[channel]) / std[channel]}\text{.}$$

# %%
import torchvision
import torchvision.transforms as transforms

# %%
batch_size = 128
root_dir = "./data/mnist/"

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, ), (0.5, )),
    #transforms.Normalize((0.13066047712053577, ), (1, )),
    transforms.Lambda(lambda x: torch.cat((x, x, x), dim=0))
])

trainset = torchvision.datasets.MNIST(root_dir, train=True, transform=transform,
                                      target_transform=None, download=True)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=False, num_workers=0)
testset = torchvision.datasets.MNIST(root_dir, train=False, transform=transform,
                                      target_transform=None, download=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                          shuffle=False, num_workers=0)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!

# %%
# this function takes the numpy input image with dim 3 x height x width
def convert_to_plt(input_image):
    input_image = input_image*np.asarray([0.5,0.5,0.5]) + np.asarray([0.5,0.5,0.5])
    return input_image

# %%
# randomly plot a sample from training set
import matplotlib.pyplot as plt

inputs = None
labels = None
for i, data in enumerate(trainloader):
    inputs, labels = data
    break

idx = np.random.randint(0, batch_size)
print("The " + str(idx) + "th image in the first " + str(batch_size) +\
      " images in the training set:")

plt_img = convert_to_plt(inputs[idx].permute(1, 2, 0).cpu().data.numpy())
plt.figure(figsize=(1,1))
plt.axis("off")
plt.imshow(plt_img)
plt.show()
print("Its correspondent label:\n" + str(labels[idx]))
# Out:
# The 61th image in the first 128 images in the training set:
# Its correspondent label:
# tensor(4)

# %% [markdown]
# ## Training on MNIST
#
# Or you can load the parameters directly.

# %%
import os.path
para_file = "./parameters/cnn_mnist.pt"
if not os.path.exists('./parameters'):
    os.makedirs('./parameters')
load_model = os.path.isfile(para_file)
print("load_model = " + str(load_model))
# Out:
# load_model = False

# %%
# %%skip (not $load_model)
# cnn.load_state_dict(torch.load(para_file))

# %% [markdown]
# ### Optimizer

# %%
import torch.optim as optim

lr_init = 0.01
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(cnn.parameters(), lr=lr_init, momentum=0.9)

def adjust_lr(optimizer, p):
    global lr_init
    lr_0 = lr_init
    alpha = 10
    beta = 0.75
    lr = lr_0 / (1 + alpha * p) ** beta
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %% [markdown]
# ### Training process

# %%
# %%skip $load_model
#
# prev_loss = np.float("inf")
# total_epoch = 30
#
# for epoch in range(total_epoch):
#     epoch_loss = 0.0
#     running_loss = 0.0
#     p = epoch * 1.0 / total_epoch
#     adjust_lr(optimizer, p)
#     for i, data in enumerate(trainloader):
#         inputs, labels = data
#         if (use_gpu):
#             inputs, labels = inputs.cuda(), labels.cuda()
#         inputs, labels = Variable(inputs), Variable(labels)
#         optimizer.zero_grad()
#         outputs, _, _ = cnn(inputs)
#         loss = criterion(outputs, labels)
#         loss.backward()
#         optimizer.step()
#         epoch_loss += loss.item()
#         running_loss += loss.item()
#         if i % 50 == 49:    # print every 50 mini-batches
#             print('[%3d] batch loss: %.3f' %
#                   (i + 1, running_loss / 50))
#             running_loss = 0.0
#     print("epoch %d loss: %.3f -> %.3f\n" % (epoch + 1, prev_loss, epoch_loss))
#     if prev_loss - epoch_loss < 0.1:
#         break
#     else:
#         prev_loss = epoch_loss
# Out:
# [ 50] batch loss: 2.229
# [100] batch loss: 0.872
# [150] batch loss: 0.324
# [200] batch loss: 0.202
# [250] batch loss: 0.187
# [300] batch loss: 0.153
# [350] batch loss: 0.152
# [400] batch loss: 0.144
# [450] batch loss: 0.097
# epoch 1 loss: inf -> 219.442
#
# [ 50] batch loss: 0.087
# [100] batch loss: 0.085
# [150] batch loss: 0.077
# [200] batch loss: 0.063
# [250] batch loss: 0.068
# [300] batch loss: 0.069
# [350] batch loss: 0.072
# [400] batch loss: 0.082
# [450] batch loss: 0.058
# epoch 2 loss: 219.442 -> 34.011
#
# [ 50] batch loss: 0.056
# [100] batch loss: 0.053
# [150] batch loss: 0.048
# [200] batch loss: 0.043
# [250] batch loss: 0.047
# [300] batch loss: 0.050
# [350] batch loss: 0.044
# [400] batch loss: 0.053
# [450] batch loss: 0.041
# epoch 3 loss: 34.011 -> 22.518
#
# [ 50] batch loss: 0.043
# [100] batch loss: 0.041
# [150] batch loss: 0.036
# [200] batch loss: 0.034
# [250] batch loss: 0.037
# [300] batch loss: 0.041
# [350] batch loss: 0.036
# [400] batch loss: 0.042
# [450] batch loss: 0.033
# epoch 4 loss: 22.518 -> 17.773
#
# [ 50] batch loss: 0.036
# [100] batch loss: 0.034
# [150] batch loss: 0.028
# [200] batch loss: 0.027
# [250] batch loss: 0.031
# [300] batch loss: 0.034
# [350] batch loss: 0.031
# [400] batch loss: 0.035
# [450] batch loss: 0.027
# epoch 5 loss: 17.773 -> 14.722
#
# [ 50] batch loss: 0.030
# [100] batch loss: 0.028
# [150] batch loss: 0.023
# [200] batch loss: 0.023
# [250] batch loss: 0.027
# [300] batch loss: 0.030
# [350] batch loss: 0.027
# [400] batch loss: 0.030
# [450] batch loss: 0.024
# epoch 6 loss: 14.722 -> 12.590
#
# [ 50] batch loss: 0.026
# [100] batch loss: 0.025
# [150] batch loss: 0.020
# [200] batch loss: 0.019
# [250] batch loss: 0.023
# [300] batch loss: 0.026
# [350] batch loss: 0.024
# [400] batch loss: 0.025
# [450] batch loss: 0.020
# epoch 7 loss: 12.590 -> 10.866
#
# [ 50] batch loss: 0.023
# [100] batch loss: 0.022
# [150] batch loss: 0.017
# [200] batch loss: 0.017
# [250] batch loss: 0.020
# [300] batch loss: 0.023
# [350] batch loss: 0.021
# [400] batch loss: 0.022
# [450] batch loss: 0.018
# epoch 8 loss: 10.866 -> 9.518
#
# [ 50] batch loss: 0.020
# [100] batch loss: 0.020
# [150] batch loss: 0.015
# [200] batch loss: 0.015
# [250] batch loss: 0.018
# [300] batch loss: 0.021
# [350] batch loss: 0.019
# [400] batch loss: 0.019
# [450] batch loss: 0.016
# epoch 9 loss: 9.518 -> 8.423
#
# [ 50] batch loss: 0.018
# [100] batch loss: 0.018
# [150] batch loss: 0.013
# [200] batch loss: 0.013
# [250] batch loss: 0.016
# [300] batch loss: 0.018
# [350] batch loss: 0.016
# [400] batch loss: 0.016
# [450] batch loss: 0.014
# epoch 10 loss: 8.423 -> 7.466
#
# [ 50] batch loss: 0.016
# [100] batch loss: 0.016
# [150] batch loss: 0.012
# [200] batch loss: 0.012
# [250] batch loss: 0.014
# [300] batch loss: 0.016
# [350] batch loss: 0.015
# [400] batch loss: 0.015
# [450] batch loss: 0.013
# epoch 11 loss: 7.466 -> 6.698
#
# [ 50] batch loss: 0.014
# [100] batch loss: 0.014
# [150] batch loss: 0.010
# [200] batch loss: 0.010
# [250] batch loss: 0.013
# [300] batch loss: 0.015
# [350] batch loss: 0.013
# [400] batch loss: 0.013
# [450] batch loss: 0.011
# epoch 12 loss: 6.698 -> 6.024
#
# [ 50] batch loss: 0.012
# [100] batch loss: 0.013
# [150] batch loss: 0.009
# [200] batch loss: 0.009
# [250] batch loss: 0.012
# [300] batch loss: 0.014
# [350] batch loss: 0.012
# [400] batch loss: 0.012
# [450] batch loss: 0.010
# epoch 13 loss: 6.024 -> 5.447
#
# [ 50] batch loss: 0.011
# [100] batch loss: 0.012
# [150] batch loss: 0.008
# [200] batch loss: 0.009
# [250] batch loss: 0.011
# [300] batch loss: 0.013
# [350] batch loss: 0.011
# [400] batch loss: 0.011
# [450] batch loss: 0.009
# epoch 14 loss: 5.447 -> 4.962
#
# [ 50] batch loss: 0.010
# [100] batch loss: 0.011
# [150] batch loss: 0.007
# [200] batch loss: 0.008
# [250] batch loss: 0.010
# [300] batch loss: 0.011
# [350] batch loss: 0.010
# [400] batch loss: 0.010
# [450] batch loss: 0.009
# epoch 15 loss: 4.962 -> 4.516
#
# [ 50] batch loss: 0.009
# [100] batch loss: 0.010
# [150] batch loss: 0.006
# [200] batch loss: 0.007
# [250] batch loss: 0.009
# [300] batch loss: 0.010
# [350] batch loss: 0.009
# [400] batch loss: 0.009
# [450] batch loss: 0.008
# epoch 16 loss: 4.516 -> 4.133
#
# [ 50] batch loss: 0.008
# [100] batch loss: 0.009
# [150] batch loss: 0.006
# [200] batch loss: 0.007
# [250] batch loss: 0.009
# [300] batch loss: 0.010
# [350] batch loss: 0.009
# [400] batch loss: 0.008
# [450] batch loss: 0.007
# epoch 17 loss: 4.133 -> 3.813
#
# [ 50] batch loss: 0.007
# [100] batch loss: 0.008
# [150] batch loss: 0.005
# [200] batch loss: 0.006
# [250] batch loss: 0.008
# [300] batch loss: 0.009
# [350] batch loss: 0.008
# [400] batch loss: 0.008
# [450] batch loss: 0.007
# epoch 18 loss: 3.813 -> 3.512
#
# [ 50] batch loss: 0.007
# [100] batch loss: 0.008
# [150] batch loss: 0.005
# [200] batch loss: 0.006
# [250] batch loss: 0.007
# [300] batch loss: 0.008
# [350] batch loss: 0.007
# [400] batch loss: 0.007
# [450] batch loss: 0.006
# epoch 19 loss: 3.512 -> 3.249
#
# [ 50] batch loss: 0.006
# [100] batch loss: 0.007
# [150] batch loss: 0.004
# [200] batch loss: 0.006
# [250] batch loss: 0.007
# [300] batch loss: 0.007
# [350] batch loss: 0.007
# [400] batch loss: 0.007
# [450] batch loss: 0.006
# epoch 20 loss: 3.249 -> 3.021
#
# [ 50] batch loss: 0.006
# [100] batch loss: 0.006
# [150] batch loss: 0.004
# [200] batch loss: 0.005
# [250] batch loss: 0.006
# [300] batch loss: 0.007
# [350] batch loss: 0.007
# [400] batch loss: 0.006
# [450] batch loss: 0.005
# epoch 21 loss: 3.021 -> 2.809
#
# [ 50] batch loss: 0.005
# [100] batch loss: 0.006
# [150] batch loss: 0.004
# [200] batch loss: 0.005
# [250] batch loss: 0.006
# [300] batch loss: 0.006
# [350] batch loss: 0.006
# [400] batch loss: 0.006
# [450] batch loss: 0.005
# epoch 22 loss: 2.809 -> 2.628
#
# [ 50] batch loss: 0.005
# [100] batch loss: 0.005
# [150] batch loss: 0.004
# [200] batch loss: 0.005
# [250] batch loss: 0.006
# [300] batch loss: 0.006
# [350] batch loss: 0.006
# [400] batch loss: 0.005
# [450] batch loss: 0.005
# epoch 23 loss: 2.628 -> 2.459
#
# [ 50] batch loss: 0.005
# [100] batch loss: 0.005
# [150] batch loss: 0.003
# [200] batch loss: 0.004
# [250] batch loss: 0.005
# [300] batch loss: 0.006
# [350] batch loss: 0.006
# [400] batch loss: 0.005
# [450] batch loss: 0.004
# epoch 24 loss: 2.459 -> 2.310
#
# [ 50] batch loss: 0.004
# [100] batch loss: 0.005
# [150] batch loss: 0.003
# [200] batch loss: 0.004
# [250] batch loss: 0.005
# [300] batch loss: 0.005
# [350] batch loss: 0.005
# [400] batch loss: 0.005
# [450] batch loss: 0.004
# epoch 25 loss: 2.310 -> 2.167
#
# [ 50] batch loss: 0.004
# [100] batch loss: 0.004
# [150] batch loss: 0.003
# [200] batch loss: 0.004
# [250] batch loss: 0.005
# [300] batch loss: 0.005
# [350] batch loss: 0.005
# [400] batch loss: 0.005
# [450] batch loss: 0.004
# epoch 26 loss: 2.167 -> 2.042
#
# [ 50] batch loss: 0.004
# [100] batch loss: 0.004
# [150] batch loss: 0.003
# [200] batch loss: 0.004
# [250] batch loss: 0.004
# [300] batch loss: 0.005
# [350] batch loss: 0.005
# [400] batch loss: 0.004
# [450] batch loss: 0.003
# epoch 27 loss: 2.042 -> 1.924
#
# [ 50] batch loss: 0.004
# [100] batch loss: 0.004
# [150] batch loss: 0.003
# [200] batch loss: 0.004
# [250] batch loss: 0.004
# [300] batch loss: 0.004
# [350] batch loss: 0.005
# [400] batch loss: 0.004
# [450] batch loss: 0.003
# epoch 28 loss: 1.924 -> 1.819
#
# [ 50] batch loss: 0.003
# [100] batch loss: 0.004
# [150] batch loss: 0.003
# [200] batch loss: 0.003
# [250] batch loss: 0.004
# [300] batch loss: 0.004
# [350] batch loss: 0.004
# [400] batch loss: 0.004
# [450] batch loss: 0.003
# epoch 29 loss: 1.819 -> 1.721

# %%
# %%skip $load_model
#
# torch.save(cnn.state_dict(), para_file)

# %% [markdown]
# ## Testing on MNIST

# %%
def evaluate_accuracy(model, dataloader):
    model.eval()
    correct = 0
    total = 0
    for i, data in enumerate(dataloader):
        inputs, labels = data
        if (use_gpu):
            inputs, labels = inputs.cuda(), labels.cuda()
        with torch.no_grad():
            #inputs, labels = Variable(inputs, volatile=True), Variable(labels, volatile=True)
            inputs, labels = Variable(inputs), Variable(labels)
            outputs, _, _ = model(inputs)
            correct += (torch.max(outputs.data, 1)[1] == labels.data).sum().item()
            total += labels.size()[0]
    acc = correct * 1.0 / total
    return acc

# %%
print("Accuracy on MNIST test set (source only): " + str(evaluate_accuracy(cnn, testloader)))
# Out:
# Accuracy on MNIST test set (source only): 0.9908

# %% [markdown]
# # MNIST-M Dataset

# %%
from my_dataset import MNIST_M

# %%
batch_size = 128
root_dir = "./data/"

transform_m = transforms.Compose([
    transforms.Resize((28, 28)),
    transforms.ToTensor(),
    #transforms.Normalize((0.4581609321206303, 0.462350402961343, 0.4084781187671726), (1, 1, 1))
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

trainset_m = MNIST_M(root_dir, train=True, transform=transform_m, download=True)
trainloader_m = torch.utils.data.DataLoader(trainset_m, batch_size=batch_size,
                                          shuffle=False, num_workers=0)
testset_m = MNIST_M(root_dir, train=False, transform=transform_m, download=True)
testloader_m = torch.utils.data.DataLoader(testset_m, batch_size=batch_size,
                                          shuffle=False, num_workers=0)

# %%
# randomly plot a sample from training set

inputs = None
labels = None
for i, data in enumerate(trainloader_m):
    inputs, labels = data
    break
    
idx = np.random.randint(0, batch_size)
print("The " + str(idx) + "th image in the first " + str(batch_size) +\
      " images in the training set:")

plt_img = convert_to_plt(inputs[idx].permute(1, 2, 0).cpu().data.numpy())
plt.figure(figsize=(1,1))
plt.axis("off")
plt.imshow(plt_img)
plt.show()
print("Its correspondent label:\n" + str(labels[idx]))
# Out:
# The 74th image in the first 128 images in the training set:
# Its correspondent label:
# tensor(0)

# %% [markdown]
# ## Testing on MNIST-M Dataset (trained on source only)

# %%
print("Accuracy on MNIST-M test set (source only): " + str(evaluate_accuracy(cnn, testloader_m)))
# Out:
# Accuracy on MNIST-M test set (source only): 0.5505555555555556

# %% [markdown]
# ## Visualization

# %%
from sklearn import manifold

def extract_features(model, dataloader):
    features = None
    lasthidden = None
    labels = None
    for i, data in enumerate(dataloader):
        inputs, labels_ = data
        if (use_gpu):
            inputs = inputs.cuda()
        inputs = Variable(inputs)
        _, f, l = model(inputs)
        if i == 0:
            features = f
            lasthidden = l
            labels = labels_
        else:
            features = torch.cat((features, f))
            lasthidden = torch.cat((lasthidden, l))
            labels = torch.cat((labels, labels_))
    features = features.data
    lasthidden = lasthidden.data
    if use_gpu:
        features = features.cpu()
        lasthidden = lasthidden.cpu()
    return features, lasthidden, labels

def visualize_single_dataset(data, labels, perplexity=50, sample_num=None):
    total_num = labels.shape[0]
    if sample_num:
        idx = np.random.choice(total_num, sample_num, replace=False)
        data, labels = data[idx, :], labels[idx]
        total_num = sample_num
    tsne = manifold.TSNE(n_components=2, init='random',
                     random_state=0, perplexity=perplexity)
    X = tsne.fit_transform(data)
    colors = ["red", "orange", "goldenrod", "yellow", "yellowgreen", "green", "teal", "blue", "violet", "purple"]
    for i in range(10):
        plt.scatter(X[labels == i, 0], X[labels == i, 1], c=colors[i], alpha=0.4)
    plt.axis("off")
    
def visualize_da(source, target, perplexity=50, sample_num=None, save=None):
    source_num = source.shape[0]
    target_num = target.shape[0]
    if sample_num:
        source, target = source[:sample_num, :], target[:sample_num, :]
        
    data = np.vstack((source, target))

    tsne = manifold.TSNE(n_components=2, init='random',
                         random_state=0, perplexity=perplexity)
    X = tsne.fit_transform(data)
    plt.scatter(X[:sample_num, 0], X[:sample_num, 1], c="blue", edgecolors=None, alpha=0.4)
    plt.scatter(X[sample_num:, 0], X[sample_num:, 1], c="red", edgecolors=None, alpha=0.4)
    plt.axis("off")
    if save:
        plt.savefig(save)
    plt.show()
    plt.clf()
    plt.close()

# %%
f, lh, l = extract_features(cnn, testloader)
f_m, lh_m, l_m = extract_features(cnn, testloader_m)

# %% [markdown]
# ### Features of MNIST test set (extracted by source only model)

# %%
visualize_single_dataset(f.numpy(), l.numpy(), perplexity=50, sample_num=1000)

# %% [markdown]
# ### Features of MNIST-M test set (extracted by source only model)

# %%
visualize_single_dataset(f_m.numpy(), l_m.numpy(), perplexity=50, sample_num=1000)

# %% [markdown]
# ### Last hidden layer of MNIST test set (extracted by source only model)

# %%
visualize_da(f.numpy(), f_m.numpy(), perplexity=50, sample_num=500,
             save="./pics/MNIST_to_MNIST_M_features_NonAdapted.svg")

# %% [markdown]
# ### Last hidden layer of MNIST-M test set (extracted by source only model)

# %%
visualize_da(lh.numpy(), lh_m.numpy(), perplexity=50, sample_num=500,
             save="./pics/MNIST_to_MNIST_M_lasthidden_NonAdapted.svg")

# %% [markdown]
# ## Training on MNIST-M Dataset

# %%
cnn_m = CNN()
if (use_gpu):
    cnn_m.cuda()
print(cnn_m)
# Out:
# CNN(
#   (C1): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#   (C2): Conv2d(32, 48, kernel_size=(5, 5), stride=(1, 1))
#   (FC1): Linear(in_features=768, out_features=100, bias=True)
#   (FC2): Linear(in_features=100, out_features=100, bias=True)
#   (FC3): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
para_file_m = "./parameters/cnn_mnist_m.pt"
load_model_m = os.path.isfile(para_file_m)
print("load_model_m = " + str(load_model_m))
# Out:
# load_model_m = False

# %%
# %%skip (not $load_model_m)
# cnn_m.load_state_dict(torch.load(para_file_m))

# %%
import torch.optim as optim

lr_init = 0.01
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(cnn_m.parameters(), lr=lr_init, momentum=0.9)

def adjust_lr(optimizer, p):
    global lr_init
    lr_0 = lr_init
    alpha = 10
    beta = 0.75
    lr = lr_0 / (1 + alpha * p) ** beta
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
# %%skip $load_model_m
#
# prev_loss = np.float("inf")
# total_epoch = 50
#
# for epoch in range(total_epoch):
#     epoch_loss = 0.0
#     running_loss = 0.0
#     p = epoch * 1.0 / total_epoch
#     adjust_lr(optimizer, p)
#     for i, data in enumerate(trainloader_m):
#         inputs, labels = data
#         if (use_gpu):
#             inputs, labels = inputs.cuda(), labels.cuda()
#
#
#         inputs, labels = Variable(inputs), Variable(labels)
#         optimizer.zero_grad()
#         outputs, _, _ = cnn_m(inputs)
#         loss = criterion(outputs, labels)
#
#         loss.backward()
#         optimizer.step()
#         epoch_loss += loss.item()
#         running_loss += loss.item()
#         if i % 50 == 49:    # print every 50 mini-batches
#             print('[%3d] batch loss: %.3f' %
#                   (i + 1, running_loss / 50))
#             running_loss = 0.0
#     print("epoch %d loss: %.3f -> %.3f\n" % (epoch + 1, prev_loss, epoch_loss))
#     if prev_loss - epoch_loss < 0.1:
#         prev_loss = epoch_loss
#         break
#     else:
#         prev_loss = epoch_loss
# Out:
# [ 50] batch loss: 2.300
# [100] batch loss: 2.292
# [150] batch loss: 2.270
# [200] batch loss: 2.130
# [250] batch loss: 1.530
# [300] batch loss: 0.927
# [350] batch loss: 0.749
# [400] batch loss: 0.576
# [450] batch loss: 0.467
# epoch 1 loss: inf -> 666.351
#
# [ 50] batch loss: 0.388
# [100] batch loss: 0.395
# [150] batch loss: 0.340
# [200] batch loss: 0.303
# [250] batch loss: 0.307
# [300] batch loss: 0.283
# [350] batch loss: 0.291
# [400] batch loss: 0.264
# [450] batch loss: 0.228
# epoch 2 loss: 666.351 -> 141.794
#
# [ 50] batch loss: 0.210
# [100] batch loss: 0.248
# [150] batch loss: 0.219
# [200] batch loss: 0.196
# [250] batch loss: 0.217
# [300] batch loss: 0.199
# [350] batch loss: 0.217
# [400] batch loss: 0.213
# [450] batch loss: 0.165
# epoch 3 loss: 141.794 -> 95.486
#
# [ 50] batch loss: 0.160
# [100] batch loss: 0.190
# [150] batch loss: 0.170
# [200] batch loss: 0.150
# [250] batch loss: 0.169
# [300] batch loss: 0.162
# [350] batch loss: 0.163
# [400] batch loss: 0.169
# [450] batch loss: 0.133
# epoch 4 loss: 95.486 -> 74.232
#
# [ 50] batch loss: 0.132
# [100] batch loss: 0.159
# [150] batch loss: 0.138
# [200] batch loss: 0.123
# [250] batch loss: 0.142
# [300] batch loss: 0.140
# [350] batch loss: 0.134
# [400] batch loss: 0.139
# [450] batch loss: 0.112
# epoch 5 loss: 74.232 -> 61.720
#
# [ 50] batch loss: 0.114
# [100] batch loss: 0.139
# [150] batch loss: 0.120
# [200] batch loss: 0.106
# [250] batch loss: 0.123
# [300] batch loss: 0.122
# [350] batch loss: 0.112
# [400] batch loss: 0.120
# [450] batch loss: 0.097
# epoch 6 loss: 61.720 -> 53.399
#
# [ 50] batch loss: 0.102
# [100] batch loss: 0.123
# [150] batch loss: 0.105
# [200] batch loss: 0.093
# [250] batch loss: 0.109
# [300] batch loss: 0.107
# [350] batch loss: 0.096
# [400] batch loss: 0.106
# [450] batch loss: 0.086
# epoch 7 loss: 53.399 -> 47.071
#
# [ 50] batch loss: 0.092
# [100] batch loss: 0.107
# [150] batch loss: 0.092
# [200] batch loss: 0.082
# [250] batch loss: 0.097
# [300] batch loss: 0.094
# [350] batch loss: 0.083
# [400] batch loss: 0.094
# [450] batch loss: 0.077
# epoch 8 loss: 47.071 -> 41.573
#
# [ 50] batch loss: 0.084
# [100] batch loss: 0.094
# [150] batch loss: 0.080
# [200] batch loss: 0.073
# [250] batch loss: 0.086
# [300] batch loss: 0.084
# [350] batch loss: 0.074
# [400] batch loss: 0.083
# [450] batch loss: 0.069
# epoch 9 loss: 41.573 -> 36.875
#
# [ 50] batch loss: 0.076
# [100] batch loss: 0.083
# [150] batch loss: 0.070
# [200] batch loss: 0.065
# [250] batch loss: 0.077
# [300] batch loss: 0.075
# [350] batch loss: 0.066
# [400] batch loss: 0.073
# [450] batch loss: 0.062
# epoch 10 loss: 36.875 -> 32.860
#
# [ 50] batch loss: 0.069
# [100] batch loss: 0.074
# [150] batch loss: 0.062
# [200] batch loss: 0.059
# [250] batch loss: 0.069
# [300] batch loss: 0.068
# [350] batch loss: 0.058
# [400] batch loss: 0.065
# [450] batch loss: 0.056
# epoch 11 loss: 32.860 -> 29.414
#
# [ 50] batch loss: 0.062
# [100] batch loss: 0.066
# [150] batch loss: 0.055
# [200] batch loss: 0.053
# [250] batch loss: 0.062
# [300] batch loss: 0.060
# [350] batch loss: 0.052
# [400] batch loss: 0.058
# [450] batch loss: 0.050
# epoch 12 loss: 29.414 -> 26.373
#
# [ 50] batch loss: 0.056
# [100] batch loss: 0.060
# [150] batch loss: 0.050
# [200] batch loss: 0.048
# [250] batch loss: 0.056
# [300] batch loss: 0.054
# [350] batch loss: 0.047
# [400] batch loss: 0.052
# [450] batch loss: 0.045
# epoch 13 loss: 26.373 -> 23.753
#
# [ 50] batch loss: 0.051
# [100] batch loss: 0.054
# [150] batch loss: 0.045
# [200] batch loss: 0.043
# [250] batch loss: 0.050
# [300] batch loss: 0.049
# [350] batch loss: 0.043
# [400] batch loss: 0.047
# [450] batch loss: 0.041
# epoch 14 loss: 23.753 -> 21.406
#
# [ 50] batch loss: 0.046
# [100] batch loss: 0.049
# [150] batch loss: 0.040
# [200] batch loss: 0.039
# [250] batch loss: 0.045
# [300] batch loss: 0.044
# [350] batch loss: 0.038
# [400] batch loss: 0.042
# [450] batch loss: 0.036
# epoch 15 loss: 21.406 -> 19.239
#
# [ 50] batch loss: 0.041
# [100] batch loss: 0.044
# [150] batch loss: 0.036
# [200] batch loss: 0.035
# [250] batch loss: 0.041
# [300] batch loss: 0.039
# [350] batch loss: 0.034
# [400] batch loss: 0.037
# [450] batch loss: 0.033
# epoch 16 loss: 19.239 -> 17.256
#
# [ 50] batch loss: 0.037
# [100] batch loss: 0.039
# [150] batch loss: 0.032
# [200] batch loss: 0.031
# [250] batch loss: 0.037
# [300] batch loss: 0.035
# [350] batch loss: 0.031
# [400] batch loss: 0.033
# [450] batch loss: 0.030
# epoch 17 loss: 17.256 -> 15.486
#
# [ 50] batch loss: 0.033
# [100] batch loss: 0.035
# [150] batch loss: 0.029
# [200] batch loss: 0.028
# [250] batch loss: 0.034
# [300] batch loss: 0.031
# [350] batch loss: 0.027
# [400] batch loss: 0.029
# [450] batch loss: 0.027
# epoch 18 loss: 15.486 -> 13.867
#
# [ 50] batch loss: 0.029
# [100] batch loss: 0.032
# [150] batch loss: 0.026
# [200] batch loss: 0.025
# [250] batch loss: 0.030
# [300] batch loss: 0.028
# [350] batch loss: 0.024
# [400] batch loss: 0.026
# [450] batch loss: 0.024
# epoch 19 loss: 13.867 -> 12.409
#
# [ 50] batch loss: 0.026
# [100] batch loss: 0.029
# [150] batch loss: 0.024
# [200] batch loss: 0.022
# [250] batch loss: 0.028
# [300] batch loss: 0.024
# [350] batch loss: 0.022
# [400] batch loss: 0.023
# [450] batch loss: 0.022
# epoch 20 loss: 12.409 -> 11.169
#
# [ 50] batch loss: 0.023
# [100] batch loss: 0.026
# [150] batch loss: 0.021
# [200] batch loss: 0.020
# [250] batch loss: 0.025
# [300] batch loss: 0.022
# [350] batch loss: 0.020
# [400] batch loss: 0.021
# [450] batch loss: 0.020
# epoch 21 loss: 11.169 -> 10.079
#
# [ 50] batch loss: 0.021
# [100] batch loss: 0.024
# [150] batch loss: 0.019
# [200] batch loss: 0.017
# [250] batch loss: 0.023
# [300] batch loss: 0.020
# [350] batch loss: 0.018
# [400] batch loss: 0.019
# [450] batch loss: 0.018
# epoch 22 loss: 10.079 -> 9.133
#
# [ 50] batch loss: 0.019
# [100] batch loss: 0.022
# [150] batch loss: 0.018
# [200] batch loss: 0.015
# [250] batch loss: 0.021
# [300] batch loss: 0.018
# [350] batch loss: 0.016
# [400] batch loss: 0.017
# [450] batch loss: 0.016
# epoch 23 loss: 9.133 -> 8.265
#
# [ 50] batch loss: 0.017
# [100] batch loss: 0.020
# [150] batch loss: 0.016
# [200] batch loss: 0.014
# [250] batch loss: 0.019
# [300] batch loss: 0.016
# [350] batch loss: 0.014
# [400] batch loss: 0.016
# [450] batch loss: 0.015
# epoch 24 loss: 8.265 -> 7.510
#
# [ 50] batch loss: 0.015
# [100] batch loss: 0.019
# [150] batch loss: 0.015
# [200] batch loss: 0.012
# [250] batch loss: 0.017
# [300] batch loss: 0.015
# [350] batch loss: 0.013
# [400] batch loss: 0.014
# [450] batch loss: 0.013
# epoch 25 loss: 7.510 -> 6.852
#
# [ 50] batch loss: 0.014
# [100] batch loss: 0.018
# [150] batch loss: 0.014
# [200] batch loss: 0.011
# [250] batch loss: 0.016
# [300] batch loss: 0.013
# [350] batch loss: 0.012
# [400] batch loss: 0.013
# [450] batch loss: 0.012
# epoch 26 loss: 6.852 -> 6.248
#
# [ 50] batch loss: 0.012
# [100] batch loss: 0.017
# [150] batch loss: 0.013
# [200] batch loss: 0.010
# [250] batch loss: 0.014
# [300] batch loss: 0.012
# [350] batch loss: 0.011
# [400] batch loss: 0.012
# [450] batch loss: 0.011
# epoch 27 loss: 6.248 -> 5.709
#
# [ 50] batch loss: 0.011
# [100] batch loss: 0.016
# [150] batch loss: 0.012
# [200] batch loss: 0.009
# [250] batch loss: 0.013
# [300] batch loss: 0.011
# [350] batch loss: 0.010
# [400] batch loss: 0.011
# [450] batch loss: 0.010
# epoch 28 loss: 5.709 -> 5.258
#
# [ 50] batch loss: 0.011
# [100] batch loss: 0.014
# [150] batch loss: 0.011
# [200] batch loss: 0.009
# [250] batch loss: 0.012
# [300] batch loss: 0.010
# [350] batch loss: 0.009
# [400] batch loss: 0.010
# [450] batch loss: 0.009
# epoch 29 loss: 5.258 -> 4.854
#
# [ 50] batch loss: 0.010
# [100] batch loss: 0.014
# [150] batch loss: 0.010
# [200] batch loss: 0.008
# [250] batch loss: 0.011
# [300] batch loss: 0.009
# [350] batch loss: 0.008
# [400] batch loss: 0.010
# [450] batch loss: 0.009
# epoch 30 loss: 4.854 -> 4.492
#
# [ 50] batch loss: 0.009
# [100] batch loss: 0.013
# [150] batch loss: 0.009
# [200] batch loss: 0.008
# [250] batch loss: 0.010
# [300] batch loss: 0.009
# [350] batch loss: 0.007
# [400] batch loss: 0.009
# [450] batch loss: 0.008
# epoch 31 loss: 4.492 -> 4.168
#
# [ 50] batch loss: 0.008
# [100] batch loss: 0.012
# [150] batch loss: 0.008
# [200] batch loss: 0.007
# [250] batch loss: 0.009
# [300] batch loss: 0.008
# [350] batch loss: 0.007
# [400] batch loss: 0.009
# [450] batch loss: 0.008
# epoch 32 loss: 4.168 -> 3.869
#
# [ 50] batch loss: 0.008
# [100] batch loss: 0.011
# [150] batch loss: 0.008
# [200] batch loss: 0.006
# [250] batch loss: 0.009
# [300] batch loss: 0.007
# [350] batch loss: 0.006
# [400] batch loss: 0.008
# [450] batch loss: 0.007
# epoch 33 loss: 3.869 -> 3.596
#
# [ 50] batch loss: 0.007
# [100] batch loss: 0.011
# [150] batch loss: 0.007
# [200] batch loss: 0.006
# [250] batch loss: 0.008
# [300] batch loss: 0.007
# [350] batch loss: 0.006
# [400] batch loss: 0.008
# [450] batch loss: 0.007
# epoch 34 loss: 3.596 -> 3.347
#
# [ 50] batch loss: 0.007
# [100] batch loss: 0.010
# [150] batch loss: 0.006
# [200] batch loss: 0.006
# [250] batch loss: 0.007
# [300] batch loss: 0.006
# [350] batch loss: 0.005
# [400] batch loss: 0.007
# [450] batch loss: 0.006
# epoch 35 loss: 3.347 -> 3.118
#
# [ 50] batch loss: 0.006
# [100] batch loss: 0.009
# [150] batch loss: 0.006
# [200] batch loss: 0.005
# [250] batch loss: 0.007
# [300] batch loss: 0.006
# [350] batch loss: 0.005
# [400] batch loss: 0.007
# [450] batch loss: 0.006
# epoch 36 loss: 3.118 -> 2.911
#
# [ 50] batch loss: 0.006
# [100] batch loss: 0.009
# [150] batch loss: 0.006
# [200] batch loss: 0.005
# [250] batch loss: 0.007
# [300] batch loss: 0.005
# [350] batch loss: 0.005
# [400] batch loss: 0.006
# [450] batch loss: 0.005
# epoch 37 loss: 2.911 -> 2.720
#
# [ 50] batch loss: 0.005
# [100] batch loss: 0.008
# [150] batch loss: 0.005
# [200] batch loss: 0.005
# [250] batch loss: 0.006
# [300] batch loss: 0.005
# [350] batch loss: 0.004
# [400] batch loss: 0.006
# [450] batch loss: 0.005
# epoch 38 loss: 2.720 -> 2.546
#
# [ 50] batch loss: 0.005
# [100] batch loss: 0.008
# [150] batch loss: 0.005
# [200] batch loss: 0.004
# [250] batch loss: 0.006
# [300] batch loss: 0.005
# [350] batch loss: 0.004
# [400] batch loss: 0.006
# [450] batch loss: 0.005
# epoch 39 loss: 2.546 -> 2.385
#
# [ 50] batch loss: 0.005
# [100] batch loss: 0.007
# [150] batch loss: 0.004
# [200] batch loss: 0.004
# [250] batch loss: 0.006
# [300] batch loss: 0.005
# [350] batch loss: 0.004
# [400] batch loss: 0.005
# [450] batch loss: 0.005
# epoch 40 loss: 2.385 -> 2.235
#
# [ 50] batch loss: 0.004
# [100] batch loss: 0.007
# [150] batch loss: 0.004
# [200] batch loss: 0.004
# [250] batch loss: 0.005
# [300] batch loss: 0.004
# [350] batch loss: 0.004
# [400] batch loss: 0.005
# [450] batch loss: 0.004
# epoch 41 loss: 2.235 -> 2.103
#
# [ 50] batch loss: 0.004
# [100] batch loss: 0.006
# [150] batch loss: 0.004
# [200] batch loss: 0.004
# [250] batch loss: 0.005
# [300] batch loss: 0.004
# [350] batch loss: 0.003
# [400] batch loss: 0.005
# [450] batch loss: 0.004
# epoch 42 loss: 2.103 -> 1.981
#
# [ 50] batch loss: 0.004
# [100] batch loss: 0.006
# [150] batch loss: 0.003
# [200] batch loss: 0.003
# [250] batch loss: 0.005
# [300] batch loss: 0.004
# [350] batch loss: 0.003
# [400] batch loss: 0.004
# [450] batch loss: 0.004
# epoch 43 loss: 1.981 -> 1.870
#
# [ 50] batch loss: 0.004
# [100] batch loss: 0.006
# [150] batch loss: 0.003
# [200] batch loss: 0.003
# [250] batch loss: 0.004
# [300] batch loss: 0.004
# [350] batch loss: 0.003
# [400] batch loss: 0.004
# [450] batch loss: 0.004
# epoch 44 loss: 1.870 -> 1.769
#
# [ 50] batch loss: 0.003
# [100] batch loss: 0.005
# [150] batch loss: 0.003
# [200] batch loss: 0.003
# [250] batch loss: 0.004
# [300] batch loss: 0.003
# [350] batch loss: 0.003
# [400] batch loss: 0.004
# [450] batch loss: 0.003
# epoch 45 loss: 1.769 -> 1.679

# %%
# %%skip $load_model_m
#
# torch.save(cnn_m.state_dict(), para_file_m)

# %%
print("Accuracy on MNIST-M test set (train on target): " + str(evaluate_accuracy(cnn_m, testloader_m)))
# Out:
# Accuracy on MNIST-M test set (train on target): 0.9631111111111111

# %% [markdown]
# # Unsupervised Domain Adaptation
#
# ## Structure (GRL)
#
# ![MNIST Structure](https://c1.staticflickr.com/1/978/41270649404_41480327ce_o.png)

# %%
from my_dataset import ST_Dataset

# %%
batch_size = 128

trainset_da = ST_Dataset(trainset, trainset_m, batch_size)
trainloader_da = torch.utils.data.DataLoader(trainset_da, batch_size=batch_size,
                                          shuffle=False, num_workers=0)

# %%
# randomly plot a sample from test set

inputs = None
labels = None
for i, data in enumerate(trainloader_da):
    inputs, labels, domain = data
    if i == 2:
        break

idx = np.random.randint(0, batch_size)
print("The " + str(idx) + "th image in the first " + str(batch_size) +\
      " images in the training set:")
plt_img = convert_to_plt(inputs[idx].permute(1, 2, 0).cpu().data.numpy())
plt.figure(figsize=(1,1))
plt.axis("off")
plt.imshow(plt_img)
plt.show()
print("Its correspondent label:")
if labels[idx].item() == -1:
    print("I don't know :)\n")
else:
    print(str(labels[idx].item()) + "\n")

print("From domain:")
if domain[idx].item() == 0:
    print("Source")
else:
    print("Target")
# Out:
# The 60th image in the first 128 images in the training set:
# Its correspondent label:
# 8
#
# From domain:
# Source

# %%
class GRL_func(torch.autograd.Function):

    @staticmethod
    def forward(ctx, inputs, lamda):
        ctx.save_for_backward(lamda)
        return inputs

    @staticmethod
    def backward(ctx, grad_outputs):
        lamda, = ctx.saved_tensors
        return -lamda * grad_outputs, None

# %%
class GRL(nn.Module):
    
    def __init__(self, lamda_init):
        super(GRL, self).__init__()
        self.GRL_func = GRL_func.apply
        self.lamda = nn.Parameter(torch.Tensor(1), requires_grad=False)
        self.set_lamda(lamda_init)
        
    def forward(self, x):
        return self.GRL_func(x, self.lamda)
    
    def set_lamda(self, lamda_new):
        self.lamda[0] = lamda_new

# %%
class CNN_DA(nn.Module):
    
    def __init__(self, lamda_init=0):
        super(CNN_DA, self).__init__()
        # lamda
        self.lamda = lamda_init
        # feature extractor
        self.C1 = nn.Conv2d(3, 32, 5)
        self.C2 = nn.Conv2d(32, 48, 5)
        # label classifier
        self.LC_FC1 = nn.Linear(48 * 4 * 4, 100)
        self.LC_FC2 = nn.Linear(100, 100)
        self.LC_FC3 = nn.Linear(100, 10)
        # domain classifier
        self.GRL_layer = GRL(lamda_init)
        self.DC_FC1 = nn.Linear(48 * 4 * 4, 100)
        self.DC_FC2 = nn.Linear(100, 1)
        
    def forward(self, x):
        # C1
        x = F.relu(self.C1(x))
        # M1
        x = F.max_pool2d(x, (2, 2))
        # C2
        x = F.relu(self.C2(x))
        # M2
        x = F.max_pool2d(x, (2, 2))
        # x's size is (128, 48, 4, 4)
        # flatten
        x = x.view(-1, 48 * 4 * 4)
        f = x
        # label classifier
        # LC_FC1
        x_l = F.relu(self.LC_FC1(x))
        # LC_FC2
        x_l = F.relu(self.LC_FC2(x_l))
        lh = x_l
        # LC_FC3
        x_l = self.LC_FC3(x_l)
        # domain classifier
        # GRL
        x_d = self.GRL_layer(x)
        # DC_FC1
        x_d = F.relu(self.DC_FC1(x_d))
        # DC_FC2
        x_d = F.sigmoid(self.DC_FC2(x_d))
        return x_l, x_d, f, lh
    
    def set_lamda(self, lamda_new):
        self.GRL_layer.set_lamda(lamda_new)

# %%
def extract_features_da(model, dataloader):
    features = None
    lasthidden = None
    labels = None
    for i, data in enumerate(dataloader):
        inputs, labels_ = data
        if (use_gpu):
            inputs = inputs.cuda()
        inputs = Variable(inputs)
        _, _, f, l = model(inputs)
        if i == 0:
            features = f
            lasthidden = l
            labels = labels_
        else:
            features = torch.cat((features, f))
            lasthidden = torch.cat((lasthidden, l))
            labels = torch.cat((labels, labels_))
    features = features.data
    lasthidden = lasthidden.data
    if use_gpu:
        features = features.cpu()
        lasthidden = lasthidden.cpu()
    return features, lasthidden, labels

# %%
cnn_da = CNN_DA(0)
if (use_gpu):
    cnn_da.cuda()
print(cnn_da)
# Out:
# CNN_DA(
#   (C1): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#   (C2): Conv2d(32, 48, kernel_size=(5, 5), stride=(1, 1))
#   (LC_FC1): Linear(in_features=768, out_features=100, bias=True)
#   (LC_FC2): Linear(in_features=100, out_features=100, bias=True)
#   (LC_FC3): Linear(in_features=100, out_features=10, bias=True)
#   (GRL_layer): GRL()
#   (DC_FC1): Linear(in_features=768, out_features=100, bias=True)
#   (DC_FC2): Linear(in_features=100, out_features=1, bias=True)
# )

# %%
para_file_da = "./parameters/cnn_mnist_to_mnist_m.pt"
load_model_da = os.path.isfile(para_file_da)
print("load_model_da = " + str(load_model_da))
# Out:
# load_model_da = False

# %%
# %%skip (not $load_model_da)
# cnn_da.load_state_dict(torch.load(para_file_da))

# %% [markdown]
# ### Optimizer

# %%
from math import exp

lr_init = 0.01
criterion_LC = nn.CrossEntropyLoss()
criterion_DC = nn.BCELoss()
optimizer = optim.SGD(filter(lambda p: p.requires_grad, cnn_da.parameters()), lr=lr_init, momentum=0.9)

def adjust_lr(optimizer, p):
    global lr_init
    lr_0 = lr_init
    alpha = 10
    beta = 0.75
    lr = lr_0 / (1 + alpha * p) ** beta
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr
    return lr
        
def adjust_lamda(model, p):
    gamma = 10
    lamda = 2 / (1 + exp(- gamma * p)) - 1
    model.set_lamda(lamda)
    return lamda

# %% [markdown]
# ### Training process

# %%
# %%skip $load_model_da
#
# prev_loss = np.float("inf")
# total_epoch = 50
#
# for epoch in range(total_epoch):
#     epoch_loss = 0.0
#     running_loss = 0.0
#     p = epoch * 1.0 / total_epoch
#     adjust_lr(optimizer, p)
#     lamda = adjust_lamda(cnn_da, p)
#     for i, data in enumerate(trainloader_da):
#         # get inputs
#         source_size = data[0].size()[0] // 2
#         inputs, labels, domains = data
#         domains = domains.to(torch.float32)
#         if (use_gpu):
#             inputs, labels, domains = inputs.cuda(), labels.cuda(), domains.cuda()
#         inputs, labels, domains = Variable(inputs), Variable(labels), Variable(domains)
#         optimizer.zero_grad()
#         # forward
#         outputs_LC, outputs_DC, f, l = cnn_da(inputs)
#         # compute loss
#         outputs_DC = outputs_DC.view(-1)
#         loss_LC = criterion_LC(outputs_LC[:source_size], labels[:source_size])
#         loss_DC = criterion_DC(outputs_DC, domains)
#         loss = loss_LC + loss_DC
#         # backward
#         loss.backward()
#         optimizer.step()
#         # stat
#         epoch_loss += loss.item()
#         running_loss += loss.item()
#         if i % 50 == 49:    # print every 50 mini-batches
#             print('[%3d] batch loss: %.3f' %
#                   (i + 1, running_loss / 50))
#             running_loss = 0.0
# #     f_da, lh_da, _ = extract_features_da(cnn_da, testloader)
# #     f_m_da, lh_m_da, _ = extract_features_da(cnn_da, testloader_m)
# #     visualize_da(f_da.numpy(), f_m_da.numpy(), perplexity=30, sample_num=200,
# #                  save="./pics/f_" + str(epoch + 1) + ".svg")
# #     visualize_da(lh_da.numpy(), lh_m_da.numpy(), perplexity=30, sample_num=200,
# #                  save="./pics/lh_" + str(epoch + 1) + ".svg")
#     print("epoch %d loss: %.3f -> %.3f\n" % (epoch + 1, prev_loss, epoch_loss))
#     if prev_loss - epoch_loss < 0.1:
#         prev_loss = epoch_loss
#         pass
#     else:
#         prev_loss = epoch_loss
# Out:
# [ 50] batch loss: 2.843
# [100] batch loss: 1.732
# [150] batch loss: 0.758
# [200] batch loss: 0.483
# [250] batch loss: 0.433
# [300] batch loss: 0.340
# [350] batch loss: 0.265
# [400] batch loss: 0.305
# [450] batch loss: 0.248
# [500] batch loss: 0.240
# [550] batch loss: 0.238
# [600] batch loss: 0.211
# [650] batch loss: 0.207
# [700] batch loss: 0.179
# [750] batch loss: 0.200
# [800] batch loss: 0.168
# [850] batch loss: 0.154
# [900] batch loss: 0.138
# epoch 1 loss: inf -> 459.420
#
# [ 50] batch loss: 0.140
# [100] batch loss: 0.137
# [150] batch loss: 0.160
# [200] batch loss: 0.152
# [250] batch loss: 0.152
# [300] batch loss: 0.161
# [350] batch loss: 0.172
# [400] batch loss: 0.179
# [450] batch loss: 0.191
# [500] batch loss: 0.157
# [550] batch loss: 0.125
# [600] batch loss: 0.132
# [650] batch loss: 0.133
# [700] batch loss: 0.123
# [750] batch loss: 0.139
# [800] batch loss: 0.117
# [850] batch loss: 0.127
# [900] batch loss: 0.111
# epoch 2 loss: 459.420 -> 132.447
#
# [ 50] batch loss: 0.119
# [100] batch loss: 0.116
# [150] batch loss: 0.135
# [200] batch loss: 0.132
# [250] batch loss: 0.129
# [300] batch loss: 0.121
# [350] batch loss: 0.113
# [400] batch loss: 0.120
# [450] batch loss: 0.140
# [500] batch loss: 0.134
# [550] batch loss: 0.133
# [600] batch loss: 0.145
# [650] batch loss: 0.147
# [700] batch loss: 0.141
# [750] batch loss: 0.146
# [800] batch loss: 0.120
# [850] batch loss: 0.137
# [900] batch loss: 0.130
# epoch 3 loss: 132.447 -> 120.640
#
# [ 50] batch loss: 0.144
# [100] batch loss: 0.134
# [150] batch loss: 0.145
# [200] batch loss: 0.161
# [250] batch loss: 0.172
# [300] batch loss: 0.186
# [350] batch loss: 0.188
# [400] batch loss: 0.194
# [450] batch loss: 0.229
# [500] batch loss: 0.197
# [550] batch loss: 0.202
# [600] batch loss: 0.198
# [650] batch loss: 0.190
# [700] batch loss: 0.203
# [750] batch loss: 0.188
# [800] batch loss: 0.172
# [850] batch loss: 0.198
# [900] batch loss: 0.183
# epoch 4 loss: 120.640 -> 168.212
#
# [ 50] batch loss: 0.207
# [100] batch loss: 0.214
# [150] batch loss: 0.263
# [200] batch loss: 0.257
# [250] batch loss: 0.231
# [300] batch loss: 0.258
# [350] batch loss: 0.297
# [400] batch loss: 0.276
# [450] batch loss: 0.324
# [500] batch loss: 0.343
# [550] batch loss: 0.337
# [600] batch loss: 0.346
# [650] batch loss: 0.330
# [700] batch loss: 0.296
# [750] batch loss: 0.318
# [800] batch loss: 0.331
# [850] batch loss: 0.253
# [900] batch loss: 0.293
# epoch 5 loss: 168.212 -> 264.807
#
# [ 50] batch loss: 0.316
# [100] batch loss: 0.321
# [150] batch loss: 0.320
# [200] batch loss: 0.439
# [250] batch loss: 0.347
# [300] batch loss: 0.300
# [350] batch loss: 0.283
# [400] batch loss: 0.329
# [450] batch loss: 0.470
# [500] batch loss: 0.425
# [550] batch loss: 0.358
# [600] batch loss: 0.401
# [650] batch loss: 0.452
# [700] batch loss: 0.418
# [750] batch loss: 0.467
# [800] batch loss: 0.386
# [850] batch loss: 0.584
# [900] batch loss: 0.401
# epoch 6 loss: 264.807 -> 358.309
#
# [ 50] batch loss: 0.386
# [100] batch loss: 0.459
# [150] batch loss: 0.479
# [200] batch loss: 0.700
# [250] batch loss: 0.363
# [300] batch loss: 0.383
# [350] batch loss: 0.517
# [400] batch loss: 0.530
# [450] batch loss: 0.480
# [500] batch loss: 0.622
# [550] batch loss: 0.565
# [600] batch loss: 0.625
# [650] batch loss: 0.570
# [700] batch loss: 0.610
# [750] batch loss: 0.643
# [800] batch loss: 0.653
# [850] batch loss: 0.737
# [900] batch loss: 0.739
# epoch 7 loss: 358.309 -> 516.278
#
# [ 50] batch loss: 0.465
# [100] batch loss: 0.494
# [150] batch loss: 0.517
# [200] batch loss: 0.550
# [250] batch loss: 0.541
# [300] batch loss: 0.607
# [350] batch loss: 0.580
# [400] batch loss: 0.489
# [450] batch loss: 0.492
# [500] batch loss: 0.493
# [550] batch loss: 0.519
# [600] batch loss: 0.649
# [650] batch loss: 0.639
# [700] batch loss: 0.541
# [750] batch loss: 0.549
# [800] batch loss: 0.474
# [850] batch loss: 0.569
# [900] batch loss: 0.569
# epoch 8 loss: 516.278 -> 500.264
#
# [ 50] batch loss: 0.411
# [100] batch loss: 0.363
# [150] batch loss: 0.448
# [200] batch loss: 0.438
# [250] batch loss: 0.536
# [300] batch loss: 0.699
# [350] batch loss: 0.476
# [400] batch loss: 0.535
# [450] batch loss: 0.625
# [500] batch loss: 0.477
# [550] batch loss: 0.467
# [600] batch loss: 0.522
# [650] batch loss: 0.638
# [700] batch loss: 0.584
# [750] batch loss: 0.643
# [800] batch loss: 0.682
# [850] batch loss: 0.683
# [900] batch loss: 0.676
# epoch 9 loss: 500.264 -> 508.300
#
# [ 50] batch loss: 0.679
# [100] batch loss: 0.688
# [150] batch loss: 0.705
# [200] batch loss: 0.745
# [250] batch loss: 0.630
# [300] batch loss: 0.558
# [350] batch loss: 0.612
# [400] batch loss: 0.619
# [450] batch loss: 0.668
# [500] batch loss: 0.655
# [550] batch loss: 0.604
# [600] batch loss: 0.620
# [650] batch loss: 0.611
# [700] batch loss: 0.727
# [750] batch loss: 0.640
# [800] batch loss: 0.513
# [850] batch loss: 0.609
# [900] batch loss: 0.627
# epoch 10 loss: 508.300 -> 588.582
#
# [ 50] batch loss: 0.605
# [100] batch loss: 0.643
# [150] batch loss: 0.577
# [200] batch loss: 0.626
# [250] batch loss: 0.576
# [300] batch loss: 0.600
# [350] batch loss: 0.629
# [400] batch loss: 0.605
# [450] batch loss: 0.645
# [500] batch loss: 0.607
# [550] batch loss: 0.621
# [600] batch loss: 0.611
# [650] batch loss: 0.648
# [700] batch loss: 0.578
# [750] batch loss: 0.630
# [800] batch loss: 0.640
# [850] batch loss: 0.634
# [900] batch loss: 0.588
# epoch 11 loss: 588.582 -> 566.440
#
# [ 50] batch loss: 0.625
# [100] batch loss: 0.606
# [150] batch loss: 0.621
# [200] batch loss: 0.568
# [250] batch loss: 0.602
# [300] batch loss: 0.593
# [350] batch loss: 0.610
# [400] batch loss: 0.619
# [450] batch loss: 0.625
# [500] batch loss: 0.586
# [550] batch loss: 0.627
# [600] batch loss: 0.603
# [650] batch loss: 0.603
# [700] batch loss: 0.622
# [750] batch loss: 0.606
# [800] batch loss: 0.592
# [850] batch loss: 0.594
# [900] batch loss: 0.602
# epoch 12 loss: 566.440 -> 559.336
#
# [ 50] batch loss: 0.731
# [100] batch loss: 0.688
# [150] batch loss: 0.617
# [200] batch loss: 0.610
# [250] batch loss: 0.602
# [300] batch loss: 0.635
# [350] batch loss: 0.640
# [400] batch loss: 0.643
# [450] batch loss: 0.640
# [500] batch loss: 0.620
# [550] batch loss: 0.640
# [600] batch loss: 0.639
# [650] batch loss: 0.643
# [700] batch loss: 0.621
# [750] batch loss: 0.619
# [800] batch loss: 0.602
# [850] batch loss: 0.631
# [900] batch loss: 0.610
# epoch 13 loss: 559.336 -> 584.358
#
# [ 50] batch loss: 0.624
# [100] batch loss: 0.611
# [150] batch loss: 0.631
# [200] batch loss: 0.633
# [250] batch loss: 0.606
# [300] batch loss: 0.613
# [350] batch loss: 0.603
# [400] batch loss: 0.626
# [450] batch loss: 0.654
# [500] batch loss: 0.628
# [550] batch loss: 0.651
# [600] batch loss: 0.649
# [650] batch loss: 0.645
# [700] batch loss: 0.624
# [750] batch loss: 0.642
# [800] batch loss: 0.629
# [850] batch loss: 0.621
# [900] batch loss: 0.624
# epoch 14 loss: 584.358 -> 579.019
#
# [ 50] batch loss: 0.640
# [100] batch loss: 0.657
# [150] batch loss: 0.684
# [200] batch loss: 0.642
# [250] batch loss: 0.636
# [300] batch loss: 0.644
# [350] batch loss: 0.640
# [400] batch loss: 0.642
# [450] batch loss: 0.663
# [500] batch loss: 0.631
# [550] batch loss: 0.655
# [600] batch loss: 0.675
# [650] batch loss: 0.666
# [700] batch loss: 0.644
# [750] batch loss: 0.653
# [800] batch loss: 0.630
# [850] batch loss: 0.663
# [900] batch loss: 0.684
# epoch 15 loss: 579.019 -> 602.024
#
# [ 50] batch loss: 0.640
# [100] batch loss: 0.635
# [150] batch loss: 0.668
# [200] batch loss: 0.640
# [250] batch loss: 0.661
# [300] batch loss: 0.624
# [350] batch loss: 0.632
# [400] batch loss: 0.631
# [450] batch loss: 0.678
# [500] batch loss: 0.641
# [550] batch loss: 0.660
# [600] batch loss: 0.668
# [650] batch loss: 0.655
# [700] batch loss: 0.649
# [750] batch loss: 0.677
# [800] batch loss: 0.656
# [850] batch loss: 0.645
# [900] batch loss: 0.639
# epoch 16 loss: 602.024 -> 598.359
#
# [ 50] batch loss: 0.648
# [100] batch loss: 0.648
# [150] batch loss: 0.690
# [200] batch loss: 0.719
# [250] batch loss: 0.651
# [300] batch loss: 0.657
# [350] batch loss: 0.659
# [400] batch loss: 0.677
# [450] batch loss: 0.687
# [500] batch loss: 0.647
# [550] batch loss: 0.655
# [600] batch loss: 0.661
# [650] batch loss: 0.661
# [700] batch loss: 0.649
# [750] batch loss: 0.697
# [800] batch loss: 0.629
# [850] batch loss: 0.681
# [900] batch loss: 0.653
# epoch 17 loss: 598.359 -> 611.983
#
# [ 50] batch loss: 0.661
# [100] batch loss: 0.640
# [150] batch loss: 0.686
# [200] batch loss: 0.659
# [250] batch loss: 0.661
# [300] batch loss: 0.638
# [350] batch loss: 0.645
# [400] batch loss: 0.666
# [450] batch loss: 0.667
# [500] batch loss: 0.661
# [550] batch loss: 0.636
# [600] batch loss: 0.665
# [650] batch loss: 0.659
# [700] batch loss: 0.647
# [750] batch loss: 0.650
# [800] batch loss: 0.638
# [850] batch loss: 0.619
# [900] batch loss: 0.642
# epoch 18 loss: 611.983 -> 600.597
#
# [ 50] batch loss: 0.635
# [100] batch loss: 0.650
# [150] batch loss: 0.673
# [200] batch loss: 0.631
# [250] batch loss: 0.635
# [300] batch loss: 0.633
# [350] batch loss: 0.643
# [400] batch loss: 0.647
# [450] batch loss: 0.660
# [500] batch loss: 0.648
# [550] batch loss: 0.648
# [600] batch loss: 0.674
# [650] batch loss: 0.653
# [700] batch loss: 0.633
# [750] batch loss: 0.662
# [800] batch loss: 0.639
# [850] batch loss: 0.633
# [900] batch loss: 0.634
# epoch 19 loss: 600.597 -> 594.803
#
# [ 50] batch loss: 0.641
# [100] batch loss: 0.661
# [150] batch loss: 0.703
# [200] batch loss: 0.625
# [250] batch loss: 0.619
# [300] batch loss: 0.616
# [350] batch loss: 0.626
# [400] batch loss: 0.667
# [450] batch loss: 0.672
# [500] batch loss: 0.622
# [550] batch loss: 0.632
# [600] batch loss: 0.646
# [650] batch loss: 0.677
# [700] batch loss: 0.645
# [750] batch loss: 0.639
# [800] batch loss: 0.624
# [850] batch loss: 0.641
# [900] batch loss: 0.645
# epoch 20 loss: 594.803 -> 592.649
#
# [ 50] batch loss: 0.634
# [100] batch loss: 0.619
# [150] batch loss: 0.697
# [200] batch loss: 0.627
# [250] batch loss: 0.631
# [300] batch loss: 0.625
# [350] batch loss: 0.671
# [400] batch loss: 0.652
# [450] batch loss: 0.679
# [500] batch loss: 0.637
# [550] batch loss: 0.650
# [600] batch loss: 0.683
# [650] batch loss: 0.666
# [700] batch loss: 0.606
# [750] batch loss: 0.644
# [800] batch loss: 0.614
# [850] batch loss: 0.620
# [900] batch loss: 0.623
# epoch 21 loss: 592.649 -> 592.615
#
# [ 50] batch loss: 0.629
# [100] batch loss: 0.635
# [150] batch loss: 0.642
# [200] batch loss: 0.614
# [250] batch loss: 0.631
# [300] batch loss: 0.625
# [350] batch loss: 0.639
# [400] batch loss: 0.632
# [450] batch loss: 0.648
# [500] batch loss: 0.620
# [550] batch loss: 0.623
# [600] batch loss: 0.644
# [650] batch loss: 0.670
# [700] batch loss: 0.617
# [750] batch loss: 0.623
# [800] batch loss: 0.618
# [850] batch loss: 0.641
# [900] batch loss: 0.631
# epoch 22 loss: 592.615 -> 581.771
#
# [ 50] batch loss: 0.633
# [100] batch loss: 0.634
# [150] batch loss: 0.647
# [200] batch loss: 0.643
# [250] batch loss: 0.643
# [300] batch loss: 0.665
# [350] batch loss: 0.621
# [400] batch loss: 0.639
# [450] batch loss: 0.667
# [500] batch loss: 0.640
# [550] batch loss: 0.647
# [600] batch loss: 0.643
# [650] batch loss: 0.713
# [700] batch loss: 0.628
# [750] batch loss: 0.641
# [800] batch loss: 0.660
# [850] batch loss: 0.648
# [900] batch loss: 0.646
# epoch 23 loss: 581.771 -> 596.697
#
# [ 50] batch loss: 0.662
# [100] batch loss: 0.654
# [150] batch loss: 0.658
# [200] batch loss: 0.648
# [250] batch loss: 0.615
# [300] batch loss: 0.644
# [350] batch loss: 0.641
# [400] batch loss: 0.648
# [450] batch loss: 0.621
# [500] batch loss: 0.675
# [550] batch loss: 0.637
# [600] batch loss: 0.694
# [650] batch loss: 0.679
# [700] batch loss: 0.708
# [750] batch loss: 0.668
# [800] batch loss: 0.660
# [850] batch loss: 0.643
# [900] batch loss: 0.622
# epoch 24 loss: 596.697 -> 602.163
#
# [ 50] batch loss: 0.642
# [100] batch loss: 0.620
# [150] batch loss: 0.643
# [200] batch loss: 0.648
# [250] batch loss: 0.673
# [300] batch loss: 0.692
# [350] batch loss: 0.643
# [400] batch loss: 0.629
# [450] batch loss: 0.664
# [500] batch loss: 0.641
# [550] batch loss: 0.664
# [600] batch loss: 0.690
# [650] batch loss: 0.686
# [700] batch loss: 0.668
# [750] batch loss: 0.655
# [800] batch loss: 0.630
# [850] batch loss: 0.663
# [900] batch loss: 0.641
# epoch 25 loss: 602.163 -> 603.332
#
# [ 50] batch loss: 0.645
# [100] batch loss: 0.628
# [150] batch loss: 0.632
# [200] batch loss: 0.648
# [250] batch loss: 0.651
# [300] batch loss: 0.667
# [350] batch loss: 0.654
# [400] batch loss: 0.643
# [450] batch loss: 0.649
# [500] batch loss: 0.674
# [550] batch loss: 0.641
# [600] batch loss: 0.657
# [650] batch loss: 0.708
# [700] batch loss: 0.661
# [750] batch loss: 0.652
# [800] batch loss: 0.645
# [850] batch loss: 0.640
# [900] batch loss: 0.643
# epoch 26 loss: 603.332 -> 601.114
#
# [ 50] batch loss: 0.634
# [100] batch loss: 0.635
# [150] batch loss: 0.645
# [200] batch loss: 0.654
# [250] batch loss: 0.638
# [300] batch loss: 0.634
# [350] batch loss: 0.632
# [400] batch loss: 0.641
# [450] batch loss: 0.640
# [500] batch loss: 0.652
# [550] batch loss: 0.623
# [600] batch loss: 0.661
# [650] batch loss: 0.662
# [700] batch loss: 0.642
# [750] batch loss: 0.649
# [800] batch loss: 0.644
# [850] batch loss: 0.661
# [900] batch loss: 0.640
# epoch 27 loss: 601.114 -> 592.536
#
# [ 50] batch loss: 0.653
# [100] batch loss: 0.643
# [150] batch loss: 0.640
# [200] batch loss: 0.639
# [250] batch loss: 0.631
# [300] batch loss: 0.633
# [350] batch loss: 0.636
# [400] batch loss: 0.629
# [450] batch loss: 0.668
# [500] batch loss: 0.641
# [550] batch loss: 0.644
# [600] batch loss: 0.647
# [650] batch loss: 0.651
# [700] batch loss: 0.633
# [750] batch loss: 0.664
# [800] batch loss: 0.618
# [850] batch loss: 0.648
# [900] batch loss: 0.646
# epoch 28 loss: 592.536 -> 594.369
#
# [ 50] batch loss: 0.694
# [100] batch loss: 0.588
# [150] batch loss: 0.655
# [200] batch loss: 0.649
# [250] batch loss: 0.671
# [300] batch loss: 0.631
# [350] batch loss: 0.627
# [400] batch loss: 0.640
# [450] batch loss: 0.655
# [500] batch loss: 0.666
# [550] batch loss: 0.636
# [600] batch loss: 0.661
# [650] batch loss: 0.632
# [700] batch loss: 0.637
# [750] batch loss: 0.649
# [800] batch loss: 0.630
# [850] batch loss: 0.640
# [900] batch loss: 0.639
# epoch 29 loss: 594.369 -> 593.944
#
# [ 50] batch loss: 0.647
# [100] batch loss: 0.655
# [150] batch loss: 0.646
# [200] batch loss: 0.646
# [250] batch loss: 0.673
# [300] batch loss: 0.636
# [350] batch loss: 0.698
# [400] batch loss: 0.695
# [450] batch loss: 0.626
# [500] batch loss: 0.640
# [550] batch loss: 0.655
# [600] batch loss: 0.666
# [650] batch loss: 0.686
# [700] batch loss: 0.679
# [750] batch loss: 0.652
# [800] batch loss: 0.654
# [850] batch loss: 0.658
# [900] batch loss: 0.651
# epoch 30 loss: 593.944 -> 606.999
#
# [ 50] batch loss: 0.683
# [100] batch loss: 0.640
# [150] batch loss: 0.663
# [200] batch loss: 0.651
# [250] batch loss: 0.650
# [300] batch loss: 0.665
# [350] batch loss: 0.662
# [400] batch loss: 0.632
# [450] batch loss: 0.667
# [500] batch loss: 0.657
# [550] batch loss: 0.681
# [600] batch loss: 0.679
# [650] batch loss: 0.661
# [700] batch loss: 0.666
# [750] batch loss: 0.660
# [800] batch loss: 0.639
# [850] batch loss: 0.649
# [900] batch loss: 0.653
# epoch 31 loss: 606.999 -> 606.664
#
# [ 50] batch loss: 0.639
# [100] batch loss: 0.659
# [150] batch loss: 0.671
# [200] batch loss: 0.653
# [250] batch loss: 0.640
# [300] batch loss: 0.631
# [350] batch loss: 0.640
# [400] batch loss: 0.678
# [450] batch loss: 0.630
# [500] batch loss: 0.578
# [550] batch loss: 0.658
# [600] batch loss: 0.686
# [650] batch loss: 0.679
# [700] batch loss: 0.660
# [750] batch loss: 0.670
# [800] batch loss: 0.659
# [850] batch loss: 0.659
# [900] batch loss: 0.657
# epoch 32 loss: 606.664 -> 601.073
#
# [ 50] batch loss: 0.654
# [100] batch loss: 0.657
# [150] batch loss: 0.668
# [200] batch loss: 0.658
# [250] batch loss: 0.646
# [300] batch loss: 0.636
# [350] batch loss: 0.657
# [400] batch loss: 0.659
# [450] batch loss: 0.657
# [500] batch loss: 0.652
# [550] batch loss: 0.644
# [600] batch loss: 0.653
# [650] batch loss: 0.647
# [700] batch loss: 0.663
# [750] batch loss: 0.638
# [800] batch loss: 0.641
# [850] batch loss: 0.642
# [900] batch loss: 0.641
# epoch 33 loss: 601.073 -> 599.488
#
# [ 50] batch loss: 0.631
# [100] batch loss: 0.636
# [150] batch loss: 0.645
# [200] batch loss: 0.635
# [250] batch loss: 0.650
# [300] batch loss: 0.645
# [350] batch loss: 0.654
# [400] batch loss: 0.656
# [450] batch loss: 0.643
# [500] batch loss: 0.646
# [550] batch loss: 0.627
# [600] batch loss: 0.656
# [650] batch loss: 0.655
# [700] batch loss: 0.638
# [750] batch loss: 0.645
# [800] batch loss: 0.638
# [850] batch loss: 0.637
# [900] batch loss: 0.635
# epoch 34 loss: 599.488 -> 592.303
#
# [ 50] batch loss: 0.631
# [100] batch loss: 0.633
# [150] batch loss: 0.658
# [200] batch loss: 0.647
# [250] batch loss: 0.654
# [300] batch loss: 0.642
# [350] batch loss: 0.654
# [400] batch loss: 0.654
# [450] batch loss: 0.672
# [500] batch loss: 0.647
# [550] batch loss: 0.637
# [600] batch loss: 0.657
# [650] batch loss: 0.646
# [700] batch loss: 0.625
# [750] batch loss: 0.691
# [800] batch loss: 0.637
# [850] batch loss: 0.637
# [900] batch loss: 0.624
# epoch 35 loss: 592.303 -> 596.149
#
# [ 50] batch loss: 0.654
# [100] batch loss: 0.653
# [150] batch loss: 0.658
# [200] batch loss: 0.647
# [250] batch loss: 0.642
# [300] batch loss: 0.620
# [350] batch loss: 0.645
# [400] batch loss: 0.644
# [450] batch loss: 0.652
# [500] batch loss: 0.643
# [550] batch loss: 0.647
# [600] batch loss: 0.668
# [650] batch loss: 0.649
# [700] batch loss: 0.675
# [750] batch loss: 0.668
# [800] batch loss: 0.659
# [850] batch loss: 0.642
# [900] batch loss: 0.657
# epoch 36 loss: 596.149 -> 599.769
#
# [ 50] batch loss: 0.639
# [100] batch loss: 0.633
# [150] batch loss: 0.651
# [200] batch loss: 0.640
# [250] batch loss: 0.648
# [300] batch loss: 0.656
# [350] batch loss: 0.652
# [400] batch loss: 0.653
# [450] batch loss: 0.650
# [500] batch loss: 0.690
# [550] batch loss: 0.693
# [600] batch loss: 0.709
# [650] batch loss: 0.710
# [700] batch loss: 0.693
# [750] batch loss: 0.729
# [800] batch loss: 0.635
# [850] batch loss: 0.629
# [900] batch loss: 0.637
# epoch 37 loss: 599.769 -> 611.085
#
# [ 50] batch loss: 0.685
# [100] batch loss: 0.660
# [150] batch loss: 0.663
# [200] batch loss: 0.661
# [250] batch loss: 0.684
# [300] batch loss: 0.643
# [350] batch loss: 0.656
# [400] batch loss: 0.659
# [450] batch loss: 0.662
# [500] batch loss: 0.667
# [550] batch loss: 0.645
# [600] batch loss: 0.680
# [650] batch loss: 0.665
# [700] batch loss: 0.652
# [750] batch loss: 0.662
# [800] batch loss: 0.646
# [850] batch loss: 0.688
# [900] batch loss: 0.656
# epoch 38 loss: 611.085 -> 610.723
#
# [ 50] batch loss: 0.647
# [100] batch loss: 0.657
# [150] batch loss: 0.638
# [200] batch loss: 0.641
# [250] batch loss: 0.644
# [300] batch loss: 0.652
# [350] batch loss: 0.637
# [400] batch loss: 0.643
# [450] batch loss: 0.666
# [500] batch loss: 0.652
# [550] batch loss: 0.641
# [600] batch loss: 0.673
# [650] batch loss: 0.660
# [700] batch loss: 0.640
# [750] batch loss: 0.683
# [800] batch loss: 0.639
# [850] batch loss: 0.671
# [900] batch loss: 0.644
# epoch 39 loss: 610.723 -> 600.772
#
# [ 50] batch loss: 0.634
# [100] batch loss: 0.646
# [150] batch loss: 0.631
# [200] batch loss: 0.658
# [250] batch loss: 0.639
# [300] batch loss: 0.648
# [350] batch loss: 0.645
# [400] batch loss: 0.655
# [450] batch loss: 0.652
# [500] batch loss: 0.659
# [550] batch loss: 0.646
# [600] batch loss: 0.679
# [650] batch loss: 0.658
# [700] batch loss: 0.642
# [750] batch loss: 0.663
# [800] batch loss: 0.648
# [850] batch loss: 0.654
# [900] batch loss: 0.638
# epoch 40 loss: 600.772 -> 598.481
#
# [ 50] batch loss: 0.642
# [100] batch loss: 0.640
# [150] batch loss: 0.640
# [200] batch loss: 0.675
# [250] batch loss: 0.675
# [300] batch loss: 0.639
# [350] batch loss: 0.634
# [400] batch loss: 0.648
# [450] batch loss: 0.659
# [500] batch loss: 0.648
# [550] batch loss: 0.649
# [600] batch loss: 0.668
# [650] batch loss: 0.656
# [700] batch loss: 0.652
# [750] batch loss: 0.669
# [800] batch loss: 0.642
# [850] batch loss: 0.658
# [900] batch loss: 0.629
# epoch 41 loss: 598.481 -> 599.841
#
# [ 50] batch loss: 0.650
# [100] batch loss: 0.658
# [150] batch loss: 0.658
# [200] batch loss: 0.666
# [250] batch loss: 0.656
# [300] batch loss: 0.639
# [350] batch loss: 0.662
# [400] batch loss: 0.649
# [450] batch loss: 0.663
# [500] batch loss: 0.665
# [550] batch loss: 0.647
# [600] batch loss: 0.667
# [650] batch loss: 0.656
# [700] batch loss: 0.660
# [750] batch loss: 0.652
# [800] batch loss: 0.644
# [850] batch loss: 0.660
# [900] batch loss: 0.654
# epoch 42 loss: 599.841 -> 604.127
#
# [ 50] batch loss: 0.653
# [100] batch loss: 0.664
# [150] batch loss: 0.655
# [200] batch loss: 0.652
# [250] batch loss: 0.652
# [300] batch loss: 0.640
# [350] batch loss: 0.652
# [400] batch loss: 0.649
# [450] batch loss: 0.653
# [500] batch loss: 0.651
# [550] batch loss: 0.640
# [600] batch loss: 0.679
# [650] batch loss: 0.656
# [700] batch loss: 0.652
# [750] batch loss: 0.660
# [800] batch loss: 0.635
# [850] batch loss: 0.666
# [900] batch loss: 0.646
# epoch 43 loss: 604.127 -> 601.333
#
# [ 50] batch loss: 0.645
# [100] batch loss: 0.646
# [150] batch loss: 0.653
# [200] batch loss: 0.656
# [250] batch loss: 0.652
# [300] batch loss: 0.650
# [350] batch loss: 0.657
# [400] batch loss: 0.640
# [450] batch loss: 0.660
# [500] batch loss: 0.653
# [550] batch loss: 0.644
# [600] batch loss: 0.680
# [650] batch loss: 0.652
# [700] batch loss: 0.645
# [750] batch loss: 0.686
# [800] batch loss: 0.648
# [850] batch loss: 0.655
# [900] batch loss: 0.651
# epoch 44 loss: 601.333 -> 602.681
#
# [ 50] batch loss: 0.645
# [100] batch loss: 0.643
# [150] batch loss: 0.655
# [200] batch loss: 0.640
# [250] batch loss: 0.654
# [300] batch loss: 0.641
# [350] batch loss: 0.660
# [400] batch loss: 0.648
# [450] batch loss: 0.648
# [500] batch loss: 0.643
# [550] batch loss: 0.634
# [600] batch loss: 0.677
# [650] batch loss: 0.652
# [700] batch loss: 0.646
# [750] batch loss: 0.653
# [800] batch loss: 0.644
# [850] batch loss: 0.646
# [900] batch loss: 0.651
# epoch 45 loss: 602.681 -> 597.601
#
# [ 50] batch loss: 0.637
# [100] batch loss: 0.645
# [150] batch loss: 0.656
# [200] batch loss: 0.630
# [250] batch loss: 0.656
# [300] batch loss: 0.644
# [350] batch loss: 0.656
# [400] batch loss: 0.651
# [450] batch loss: 0.665
# [500] batch loss: 0.659
# [550] batch loss: 0.651
# [600] batch loss: 0.668
# [650] batch loss: 0.651
# [700] batch loss: 0.652
# [750] batch loss: 0.651
# [800] batch loss: 0.642
# [850] batch loss: 0.650
# [900] batch loss: 0.656
# epoch 46 loss: 597.601 -> 599.528
#
# [ 50] batch loss: 0.629
# [100] batch loss: 0.644
# [150] batch loss: 0.661
# [200] batch loss: 0.632
# [250] batch loss: 0.653
# [300] batch loss: 0.644
# [350] batch loss: 0.651
# [400] batch loss: 0.661
# [450] batch loss: 0.665
# [500] batch loss: 0.664
# [550] batch loss: 0.650
# [600] batch loss: 0.661
# [650] batch loss: 0.671
# [700] batch loss: 0.646
# [750] batch loss: 0.649
# [800] batch loss: 0.643
# [850] batch loss: 0.657
# [900] batch loss: 0.659
# epoch 47 loss: 599.528 -> 600.732
#
# [ 50] batch loss: 0.636
# [100] batch loss: 0.662
# [150] batch loss: 0.657
# [200] batch loss: 0.649
# [250] batch loss: 0.648
# [300] batch loss: 0.647
# [350] batch loss: 0.641
# [400] batch loss: 0.661
# [450] batch loss: 0.656
# [500] batch loss: 0.661
# [550] batch loss: 0.651
# [600] batch loss: 0.687
# [650] batch loss: 0.667
# [700] batch loss: 0.680
# [750] batch loss: 0.650
# [800] batch loss: 0.643
# [850] batch loss: 0.679
# [900] batch loss: 0.650
# epoch 48 loss: 600.732 -> 605.428
#
# [ 50] batch loss: 0.643
# [100] batch loss: 0.656
# [150] batch loss: 0.653
# [200] batch loss: 0.646
# [250] batch loss: 0.656
# [300] batch loss: 0.644
# [350] batch loss: 0.644
# [400] batch loss: 0.660
# [450] batch loss: 0.651
# [500] batch loss: 0.658
# [550] batch loss: 0.646
# [600] batch loss: 0.685
# [650] batch loss: 0.662
# [700] batch loss: 0.654
# [750] batch loss: 0.660
# [800] batch loss: 0.652
# [850] batch loss: 0.656
# [900] batch loss: 0.664
# epoch 49 loss: 605.428 -> 603.242
#
# [ 50] batch loss: 0.639
# [100] batch loss: 0.655
# [150] batch loss: 0.657
# [200] batch loss: 0.666
# [250] batch loss: 0.642
# [300] batch loss: 0.658
# [350] batch loss: 0.661
# [400] batch loss: 0.670
# [450] batch loss: 0.670
# [500] batch loss: 0.664
# [550] batch loss: 0.652
# [600] batch loss: 0.689
# [650] batch loss: 0.659
# [700] batch loss: 0.663
# [750] batch loss: 0.658
# [800] batch loss: 0.649
# [850] batch loss: 0.654
# [900] batch loss: 0.651
# epoch 50 loss: 603.242 -> 606.649

# %%
# %%skip $load_model_da
#
# torch.save(cnn_da.state_dict(), para_file_da)

# %% [markdown]
# ### Test on MNIST and MNIST-M dataset

# %%
def evaluate_da_accuracy(model, dataloader, source):
    model.eval()
    correct_LC = 0
    correct_DC = 0
    total = 0
    
    with torch.no_grad():
        for i, data in enumerate(dataloader):
            inputs, labels = data
            if (use_gpu):
                inputs, labels = inputs.cuda(), labels.cuda()
            inputs, labels = Variable(inputs), Variable(labels)
            outputs_LC, outputs_DC, _, _ = model(inputs)
            correct_LC += (torch.max(outputs_LC.data, 1)[1] == labels.data).sum().item()
            if source:
                correct_DC += labels.size()[0] - outputs_DC.data.sum().item()
            else:
                correct_DC += outputs_DC.data.sum().item()
            total += labels.size()[0]
        acc_LC = correct_LC / total
        acc_DC = correct_DC / total
    return acc_LC, acc_DC

# %%
print(("Label classifier accuracy on MNIST test set (DA): %f\n"
       "Domain classifier accuracy on MNIST test set (DA): %f")
      # %evaluate_da_accuracy(cnn_da, testloader, source=True))
# Out:
# Label classifier accuracy on MNIST test set (DA): 0.983300
# Domain classifier accuracy on MNIST test set (DA): 0.577271

# %%
print(("Label classifier accuracy on MNIST-M test set (DA): %f\n"
       "Domain classifier accuracy on MNIST-M test set (DA): %f")
      # %evaluate_da_accuracy(cnn_da, testloader_m, source=True))
# Out:
# Label classifier accuracy on MNIST-M test set (DA): 0.827333
# Domain classifier accuracy on MNIST-M test set (DA): 0.437314

# %% [markdown]
# ### Visualization

# %%
f_da, lh_da, l_da = extract_features_da(cnn_da, testloader)
f_m_da, lh_m_da, l_m_da = extract_features_da(cnn_da, testloader_m)

# %% [markdown]
# Features of MNIST test set (extracted by DA model)

# %%
visualize_da(f_da.numpy(), f_m_da.numpy(), perplexity=50, sample_num=500,
             save="./pics/MNIST_to_MNIST_M_features_Adapted.svg")

# %% [markdown]
# Features of MNIST-M test set (extracted by DA model)

# %%
visualize_da(lh_da.numpy(), lh_m_da.numpy(), perplexity=50, sample_num=500,
             save="./pics/MNIST_to_MNIST_M_lasthidden_Adapted.svg")
