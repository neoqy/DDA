# %%
import torch
import torchvision
import os.path

import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

from sklearn import manifold
from math import exp, sqrt
from torch.autograd import Variable
from my_dataset import MNIST_M
from my_dataset import ST_Dataset

# %matplotlib inline
# %load_ext skip_kernel_extension

import torch.utils.model_zoo as model_zoo

from data_loader import get_train_test_loader, get_office31_dataloader

use_gpu = torch.cuda.is_available()
print("use_gpu = " + str(use_gpu))

def reset_seq(seq):
    for m in seq:
        if isinstance(m, nn.Conv2d):
            n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
            m.weight.data.normal_(0, sqrt(2 / n))
            if m.bias is not None:
                m.bias.data.zero_()
        elif isinstance(m, nn.Linear):
            size = m.weight.size()
            fan_out = size[0] # number of rows
            fan_in = size[1] # number of columns
            m.weight.data.normal_(0, sqrt(2 / (fan_in + fan_out)))
            m.bias.data.zero_()
        elif hasattr(m, 'reset_parameters'):
            m.reset_parameters()
            
def evaluate_da_accuracy(model, dataloader, source):
    model.eval()
    correct_LC = 0
    correct_DC = 0
    total = 0
    
    with torch.no_grad():
        for i, data in enumerate(dataloader):
            inputs, labels = data
            if (use_gpu):
                inputs, labels = inputs.cuda(), labels.cuda()
            inputs, labels = Variable(inputs), Variable(labels)
            outputs_LC, outputs_DC = model(inputs)
            correct_LC += (torch.max(outputs_LC.data, 1)[1] == labels.data).sum().item()
            if source:
                correct_DC += labels.size()[0] - outputs_DC.data.sum().item()
            else:
                correct_DC += outputs_DC.data.sum().item()
            total += labels.size()[0]
        acc_LC = correct_LC / total
        acc_DC = correct_DC / total
    return acc_LC, acc_DC
# Out:
# use_gpu = True

# %%
trainloader_dslr = get_office31_dataloader("dslr", batch_size=49)
# Out:
# [INFO] Loading datasets: dslr

# %%
trainloader_webcam = get_office31_dataloader("webcam", batch_size=79)
# Out:
# [INFO] Loading datasets: webcam

# %%
class GRL_func(torch.autograd.Function):

    @staticmethod
    def forward(ctx, inputs, lamda):
        ctx.save_for_backward(lamda)
        return inputs

    @staticmethod
    def backward(ctx, grad_outputs):
        lamda, = ctx.saved_tensors
        return -lamda * grad_outputs, None

class GRL(nn.Module):
    
    def __init__(self, lamda_init):
        super(GRL, self).__init__()
        self.GRL_func = GRL_func.apply
        self.lamda = nn.Parameter(torch.Tensor(1), requires_grad=False)
        self.set_lamda(lamda_init)
        
    def forward(self, x):
        return self.GRL_func(x, self.lamda)
    
    def set_lamda(self, lamda_new):
        self.lamda[0] = lamda_new

# %%
class AlexNet_DA(nn.Module):

    def __init__(self, lamda_init):
        super(AlexNet_DA, self).__init__()
        # lambda
        self.lamda = lamda_init
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, 256),
            nn.ReLU(inplace=True)
        )
        self.label_classifier = nn.Sequential(
            nn.Linear(256, 31)
        )
        self.GRL_layer = GRL(lamda_init)
        self.domain_classifier = nn.Sequential(
            nn.Linear(256, 1024),
            nn.ReLU(inplace=True),
            nn.Linear(1024, 1024),
            nn.ReLU(inplace=True),
            nn.Linear(1024, 256),
            nn.ReLU(inplace=True),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), 256 * 6 * 6)
        x = self.classifier(x)
        x_l = self.label_classifier(x)
        x_d = self.GRL_layer(x)
        x_d = self.domain_classifier(x_d)
        return x_l, x_d
    
    def set_lamda(self, lamda_new):
        self.GRL_layer.set_lamda(lamda_new)
    
    def load_pretrained_part(self, state_dict):
        own_state = self.state_dict()
        for name, param in state_dict.items():
            if name not in own_state:
                continue
            if isinstance(param, nn.Parameter):
                # backwards compatibility for serialized parameters
                param = param.data
            own_state[name].copy_(param)

# %%
cnn_da = AlexNet_DA(0)

model_url = "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth"

cnn_da.load_pretrained_part(model_zoo.load_url(model_url))

if (use_gpu):
    cnn_da.cuda()
print(cnn_da)
# Out:
# AlexNet_DA(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace)
#     (3): Dropout(p=0.5)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace)
#     (6): Dropout(p=0.5)
#     (7): Linear(in_features=4096, out_features=256, bias=True)
#     (8): ReLU(inplace)
#   )
#   (label_classifier): Sequential(
#     (0): Linear(in_features=256, out_features=31, bias=True)
#   )
#   (GRL_layer): GRL()
#   (domain_classifier): Sequential(
#     (0): Linear(in_features=256, out_features=1024, bias=True)
#     (1): ReLU(inplace)
#     (2): Linear(in_features=1024, out_features=1024, bias=True)
#     (3): ReLU(inplace)
#     (4): Linear(in_features=1024, out_features=256, bias=True)
#     (5): ReLU(inplace)
#     (6): Linear(in_features=256, out_features=1, bias=True)
#     (7): Sigmoid()
#   )
# )

# %%
para_file_dslr = "./parameters/cnn_dslr_to_webcam_source_only.pt"
load_model_dslr = os.path.isfile(para_file_dslr)
print(load_model_dslr)
# Out:
# True

# %%
for param in cnn_da.features.parameters():
    param.requires_grad = False

lr_init = 0.01
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(filter(lambda p: p.requires_grad, cnn_da.parameters()), lr=lr_init, momentum=0.9)

def adjust_lr(optimizer, p):
    global lr_init
    lr_0 = lr_init
    alpha = 10
    beta = 0.75
    lr = lr_0 / (1 + alpha * p) ** beta
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr
    return lr

# %%
prev_loss = np.float("inf")
total_epoch = 10
finetune_epoch_start = 20
#reset_seq(cnn_da.classifier)
reset_seq(cnn_da.label_classifier)

early_stop_cnt = 0

for epoch in range(total_epoch):
    epoch_loss = 0.0
    running_loss = 0.0
    p = epoch * 1.0 / total_epoch
    lr = adjust_lr(optimizer, p)
    if epoch == finetune_epoch_start:
        for param in cnn_da.features.parameters():
            param.requires_grad = True
        optimizer = optim.SGD(filter(lambda p: p.requires_grad, cnn_da.parameters()), lr=lr, momentum=0.9)
    for i, data in enumerate(trainloader_dslr):
        inputs, labels = data
        if (use_gpu):
            inputs, labels = inputs.cuda(), labels.cuda()
        inputs, labels = Variable(inputs), Variable(labels)
        optimizer.zero_grad()
        outputs_LC, _ = cnn_da(inputs)
        loss = criterion(outputs_LC, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        running_loss += loss.item()
        if i % 2 == 1:    # print every 50 mini-batches
            print('[%2d] batch loss: %.3f' %
                  (i + 1, running_loss / 2))
            running_loss = 0.0
    print("epoch %d loss: %.3f -> %.3f\n" % (epoch + 1, prev_loss, epoch_loss))
    if prev_loss - epoch_loss < 0.1:
        prev_loss = epoch_loss
        if epoch > finetune_epoch_start:
            early_stop_cnt += 1
            if early_stop_cnt > 2:
                break
    else:
        early_stop_cnt = 0
        prev_loss = epoch_loss
# Out:
# [ 2] batch loss: 3.625
# [ 4] batch loss: 6.135
# [ 6] batch loss: 4.907
# [ 8] batch loss: 4.585
# [10] batch loss: 4.508
# epoch 1 loss: inf -> 51.622
#
# [ 2] batch loss: 1.235
# [ 4] batch loss: 2.368
# [ 6] batch loss: 2.375
# [ 8] batch loss: 2.524
# [10] batch loss: 2.663
# epoch 2 loss: 51.622 -> 23.105
#
# [ 2] batch loss: 0.645
# [ 4] batch loss: 1.399
# [ 6] batch loss: 1.200
# [ 8] batch loss: 1.656
# [10] batch loss: 1.785
# epoch 3 loss: 23.105 -> 13.486
#
# [ 2] batch loss: 0.413
# [ 4] batch loss: 0.664
# [ 6] batch loss: 0.465
# [ 8] batch loss: 0.869
# [10] batch loss: 1.081
# epoch 4 loss: 13.486 -> 6.997
#
# [ 2] batch loss: 0.297
# [ 4] batch loss: 0.418
# [ 6] batch loss: 0.274
# [ 8] batch loss: 0.479
# [10] batch loss: 0.562
# epoch 5 loss: 6.997 -> 4.069
#
# [ 2] batch loss: 0.130
# [ 4] batch loss: 0.269
# [ 6] batch loss: 0.288
# [ 8] batch loss: 0.231
# [10] batch loss: 0.426
# epoch 6 loss: 4.069 -> 2.692
#
# [ 2] batch loss: 0.047
# [ 4] batch loss: 0.160
# [ 6] batch loss: 0.114
# [ 8] batch loss: 0.265
# [10] batch loss: 0.301
# epoch 7 loss: 2.692 -> 1.779
#
# [ 2] batch loss: 0.039
# [ 4] batch loss: 0.102
# [ 6] batch loss: 0.075
# [ 8] batch loss: 0.149
# [10] batch loss: 0.197
# epoch 8 loss: 1.779 -> 1.129
#
# [ 2] batch loss: 0.066
# [ 4] batch loss: 0.122
# [ 6] batch loss: 0.075
# [ 8] batch loss: 0.110
# [10] batch loss: 0.219
# epoch 9 loss: 1.129 -> 1.186
#
# [ 2] batch loss: 0.035
# [ 4] batch loss: 0.092
# [ 6] batch loss: 0.052
# [ 8] batch loss: 0.118
# [10] batch loss: 0.152
# epoch 10 loss: 1.186 -> 0.901

# %%
evaluate_da_accuracy(cnn_da, trainloader_dslr, source=True)
# Out:
# (1.0, 0.532371352475331)

# %%
evaluate_da_accuracy(cnn_da, trainloader_webcam, source=False)
# Out:
# (0.9144654088050315, 0.47331236773316965)

# %%
#torch.save(cnn_da.state_dict(), para_file_dslr)

# %%
#cnn_da.load_pretrained_part(torch.load(para_file_dslr))

# %%
from math import exp

lr_init = 0.01
criterion_LC = nn.CrossEntropyLoss()
criterion_DC = nn.BCELoss()
optimizer = optim.SGD(filter(lambda p: p.requires_grad, cnn_da.parameters()), lr=lr_init, momentum=0.9)

def adjust_lr(optimizer, p):
    global lr_init
    lr_0 = lr_init
    alpha = 10
    beta = 0.75
    lr = lr_0 / (1 + alpha * p) ** beta
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr
    return lr

def adjust_lamda(model, p):
    gamma = 10
    lamda = 2 / (1 + exp(- gamma * p)) - 1
    model.set_lamda(lamda)
    return lamda

# %%
for param in cnn_da.features.parameters():
    param.requires_grad = True

# %%
prev_loss = np.float("inf")
prev_loss_LC = np.float("inf")
prev_loss_DC = np.float("inf")
total_epoch = 100
reset_seq(cnn_da.domain_classifier)

for epoch in range(total_epoch):
    epoch_loss = 0.0
    epoch_loss_LC = 0.0
    epoch_loss_DC = 0.0
    running_loss = 0.0
    p = epoch * 1.0 / total_epoch
    lr = adjust_lr(optimizer, p)
    dslr_iter = iter(trainloader_dslr)
    webcam_iter = iter(trainloader_webcam)
    i = 0
    while True:
        try:
            images_s, labels_s = dslr_iter.next()
            images_t, labels_t = webcam_iter.next()
        except:
            break
        inputs, labels = torch.cat((images_s, images_t)), torch.cat((labels_s, labels_t))
        source_size, target_size = labels_s.size(0), labels_t.size(0)
        domains = torch.cat((torch.zeros(source_size), torch.ones(target_size)))
        if (use_gpu):
            inputs, labels, domains = inputs.cuda(), labels.cuda(), domains.cuda()
        inputs, labels, domains = Variable(inputs), Variable(labels), Variable(domains)
        optimizer.zero_grad()
        outputs_LC, outputs_DC = cnn_da(inputs)
        loss_LC = criterion_LC(outputs_LC[:source_size], labels[:source_size])
        loss_DC = criterion_DC(outputs_DC.view(-1), domains)
        loss = loss_LC + loss_DC
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        epoch_loss_LC += loss_LC.item()
        epoch_loss_DC += loss_DC.item()
        running_loss += loss.item()
        if i % 2 == 1:    # print every 50 mini-batches
            print('[%2d] batch loss: %.3f' %
                  (i + 1, running_loss / 2))
            running_loss = 0.0
        i += 1
    print("epoch %d loss: %.3f -> %.3f" % (epoch + 1, prev_loss, epoch_loss))
    print("LC loss: %.3f -> %.3f" % (prev_loss_LC, epoch_loss_LC))
    print("DC loss: %.3f -> %.3f" % (prev_loss_DC, epoch_loss_DC))
    if epoch % 10 == 9:
        acc_l, acc_d = evaluate_da_accuracy(cnn_da, trainloader_webcam, source=False)
        print(acc_l, acc_d)
    print()
    prev_loss = epoch_loss
    prev_loss_LC = epoch_loss_LC
    prev_loss_DC = epoch_loss_DC
# Out:
# [ 2] batch loss: 0.677
# [ 4] batch loss: 0.714
# [ 6] batch loss: 0.690
# [ 8] batch loss: 0.745
# [10] batch loss: 0.773
# epoch 1 loss: inf -> 7.918
# LC loss: inf -> 0.344
# DC loss: inf -> 7.574
#
# [ 2] batch loss: 0.836
# [ 4] batch loss: 0.736
# [ 6] batch loss: 0.721
# [ 8] batch loss: 0.733
# [10] batch loss: 0.724
# epoch 2 loss: 7.918 -> 8.273
# LC loss: 0.344 -> 0.195
# DC loss: 7.574 -> 8.078
#
# [ 2] batch loss: 0.650
# [ 4] batch loss: 0.669
# [ 6] batch loss: 0.631
# [ 8] batch loss: 0.658
# [10] batch loss: 0.696
# epoch 3 loss: 8.273 -> 7.642
# LC loss: 0.195 -> 0.207
# DC loss: 8.078 -> 7.435
#
# [ 2] batch loss: 0.619
# [ 4] batch loss: 0.688
# [ 6] batch loss: 0.683
# [ 8] batch loss: 0.667
# [10] batch loss: 0.905
# epoch 4 loss: 7.642 -> 7.612
# LC loss: 0.207 -> 0.709
# DC loss: 7.435 -> 6.903
#
# [ 2] batch loss: 0.583
# [ 4] batch loss: 0.703
# [ 6] batch loss: 0.655
# [ 8] batch loss: 0.782
# [10] batch loss: 2.174
# epoch 5 loss: 7.612 -> 10.313
# LC loss: 0.709 -> 3.552
# DC loss: 6.903 -> 6.761
#
# [ 2] batch loss: 0.621
# [ 4] batch loss: 0.644
# [ 6] batch loss: 0.643
# [ 8] batch loss: 0.688
# [10] batch loss: 1.884
# epoch 6 loss: 10.313 -> 9.606
# LC loss: 3.552 -> 2.727
# DC loss: 6.761 -> 6.879
#
# [ 2] batch loss: 0.570
# [ 4] batch loss: 0.640
# [ 6] batch loss: 0.642
# [ 8] batch loss: 0.766
# [10] batch loss: 1.018
# epoch 7 loss: 9.606 -> 7.774
# LC loss: 2.727 -> 1.159
# DC loss: 6.879 -> 6.615
#
# [ 2] batch loss: 0.562
# [ 4] batch loss: 0.641
# [ 6] batch loss: 0.618
# [ 8] batch loss: 0.668
# [10] batch loss: 0.722
# epoch 8 loss: 7.774 -> 6.829
# LC loss: 1.159 -> 0.467
# DC loss: 6.615 -> 6.362
#
# [ 2] batch loss: 0.545
# [ 4] batch loss: 0.621
# [ 6] batch loss: 0.577
# [ 8] batch loss: 0.607
# [10] batch loss: 0.603
# epoch 9 loss: 6.829 -> 6.208
# LC loss: 0.467 -> 0.184
# DC loss: 6.362 -> 6.024
#
# [ 2] batch loss: 0.503
# [ 4] batch loss: 0.595
# [ 6] batch loss: 0.551
# [ 8] batch loss: 0.578
# [10] batch loss: 0.556
# epoch 10 loss: 6.208 -> 5.829
# LC loss: 0.184 -> 0.100
# DC loss: 6.024 -> 5.729
# 0.9169811320754717 0.6208959987328487
#
# [ 2] batch loss: 0.494
# [ 4] batch loss: 0.563
# [ 6] batch loss: 0.547
# [ 8] batch loss: 0.561
# [10] batch loss: 0.529
# epoch 11 loss: 5.829 -> 5.685
# LC loss: 0.100 -> 0.069
# DC loss: 5.729 -> 5.615
#
# [ 2] batch loss: 0.523
# [ 4] batch loss: 0.683
# [ 6] batch loss: 0.538
# [ 8] batch loss: 0.564
# [10] batch loss: 0.536
# epoch 12 loss: 5.685 -> 5.884
# LC loss: 0.069 -> 0.055
# DC loss: 5.615 -> 5.829
#
# [ 2] batch loss: 0.583
# [ 4] batch loss: 0.607
# [ 6] batch loss: 0.537
# [ 8] batch loss: 0.665
# [10] batch loss: 0.576
# epoch 13 loss: 5.884 -> 6.206
# LC loss: 0.055 -> 0.046
# DC loss: 5.829 -> 6.160
#
# [ 2] batch loss: 0.502
# [ 4] batch loss: 0.642
# [ 6] batch loss: 0.617
# [ 8] batch loss: 0.602
# [10] batch loss: 0.539
# epoch 14 loss: 6.206 -> 6.175
# LC loss: 0.046 -> 0.040
# DC loss: 6.160 -> 6.135
#
# [ 2] batch loss: 0.635
# [ 4] batch loss: 0.885
# [ 6] batch loss: 0.618
# [ 8] batch loss: 0.573
# [10] batch loss: 0.556
# epoch 15 loss: 6.175 -> 6.800
# LC loss: 0.040 -> 0.036
# DC loss: 6.135 -> 6.764
#
# [ 2] batch loss: 0.543
# [ 4] batch loss: 0.608
# [ 6] batch loss: 0.555
# [ 8] batch loss: 0.582
# [10] batch loss: 0.517
# epoch 16 loss: 6.800 -> 5.816
# LC loss: 0.036 -> 0.033
# DC loss: 6.764 -> 5.783
#
# [ 2] batch loss: 0.451
# [ 4] batch loss: 0.555
# [ 6] batch loss: 0.502
# [ 8] batch loss: 0.538
# [10] batch loss: 0.467
# epoch 17 loss: 5.816 -> 5.165
# LC loss: 0.033 -> 0.030
# DC loss: 5.783 -> 5.135
#
# [ 2] batch loss: 0.435
# [ 4] batch loss: 0.522
# [ 6] batch loss: 0.486
# [ 8] batch loss: 0.511
# [10] batch loss: 0.444
# epoch 18 loss: 5.165 -> 4.910
# LC loss: 0.030 -> 0.028
# DC loss: 5.135 -> 4.883
#
# [ 2] batch loss: 0.395
# [ 4] batch loss: 0.501
# [ 6] batch loss: 0.455
# [ 8] batch loss: 0.478
# [10] batch loss: 0.422
# epoch 19 loss: 4.910 -> 4.590
# LC loss: 0.028 -> 0.026
# DC loss: 4.883 -> 4.564
#
# [ 2] batch loss: 0.360
# [ 4] batch loss: 0.473
# [ 6] batch loss: 0.429
# [ 8] batch loss: 0.457
# [10] batch loss: 0.397
# epoch 20 loss: 4.590 -> 4.294
# LC loss: 0.026 -> 0.024
# DC loss: 4.564 -> 4.270
# 0.919496855345912 0.6905526341132397
#
# [ 2] batch loss: 0.359
# [ 4] batch loss: 0.448
# [ 6] batch loss: 0.415
# [ 8] batch loss: 0.452
# [10] batch loss: 0.387
# epoch 21 loss: 4.294 -> 4.193
# LC loss: 0.024 -> 0.023
# DC loss: 4.270 -> 4.170
#
# [ 2] batch loss: 0.337
# [ 4] batch loss: 0.483
# [ 6] batch loss: 0.400
# [ 8] batch loss: 0.437
# [10] batch loss: 0.381
# epoch 22 loss: 4.193 -> 4.122
# LC loss: 0.023 -> 0.022
# DC loss: 4.170 -> 4.100
#
# [ 2] batch loss: 0.334
# [ 4] batch loss: 0.432
# [ 6] batch loss: 0.453
# [ 8] batch loss: 0.503
# [10] batch loss: 0.366
# epoch 23 loss: 4.122 -> 4.224
# LC loss: 0.022 -> 0.021
# DC loss: 4.100 -> 4.204
#
# [ 2] batch loss: 0.375
# [ 4] batch loss: 0.684
# [ 6] batch loss: 0.408
# [ 8] batch loss: 0.493
# [10] batch loss: 0.528
# epoch 24 loss: 4.224 -> 5.334
# LC loss: 0.021 -> 0.020
# DC loss: 4.204 -> 5.314
#
# [ 2] batch loss: 0.675
# [ 4] batch loss: 0.542
# [ 6] batch loss: 0.648
# [ 8] batch loss: 0.846
# [10] batch loss: 0.885
# epoch 25 loss: 5.334 -> 10.383
# LC loss: 0.020 -> 0.019
# DC loss: 5.314 -> 10.364
#
# [ 2] batch loss: 0.470
# [ 4] batch loss: 0.758
# [ 6] batch loss: 0.760
# [ 8] batch loss: 0.642
# [10] batch loss: 0.605
# epoch 26 loss: 10.383 -> 6.840
# LC loss: 0.019 -> 0.018
# DC loss: 10.364 -> 6.821
#
# [ 2] batch loss: 0.496
# [ 4] batch loss: 0.578
# [ 6] batch loss: 0.551
# [ 8] batch loss: 0.572
# [10] batch loss: 0.544
# epoch 27 loss: 6.840 -> 5.790
# LC loss: 0.018 -> 0.018
# DC loss: 6.821 -> 5.772
#
# [ 2] batch loss: 0.472
# [ 4] batch loss: 0.567
# [ 6] batch loss: 0.522
# [ 8] batch loss: 0.533
# [10] batch loss: 0.521
# epoch 28 loss: 5.790 -> 5.513
# LC loss: 0.018 -> 0.017
# DC loss: 5.772 -> 5.496
#
# [ 2] batch loss: 0.440
# [ 4] batch loss: 0.539
# [ 6] batch loss: 0.502
# [ 8] batch loss: 0.504
# [10] batch loss: 0.486
# epoch 29 loss: 5.513 -> 5.159
# LC loss: 0.017 -> 0.017
# DC loss: 5.496 -> 5.142
#
# [ 2] batch loss: 0.402
# [ 4] batch loss: 0.514
# [ 6] batch loss: 0.475
# [ 8] batch loss: 0.481
# [10] batch loss: 0.461
# epoch 30 loss: 5.159 -> 4.836
# LC loss: 0.017 -> 0.016
# DC loss: 5.142 -> 4.820
# 0.9220125786163522 0.6734111983821077
#
# [ 2] batch loss: 0.377
# [ 4] batch loss: 0.491
# [ 6] batch loss: 0.453
# [ 8] batch loss: 0.459
# [10] batch loss: 0.436
# epoch 31 loss: 4.836 -> 4.569
# LC loss: 0.016 -> 0.016
# DC loss: 4.820 -> 4.553
#
# [ 2] batch loss: 0.348
# [ 4] batch loss: 0.467
# [ 6] batch loss: 0.427
# [ 8] batch loss: 0.438
# [10] batch loss: 0.413
# epoch 32 loss: 4.569 -> 4.299
# LC loss: 0.016 -> 0.015
# DC loss: 4.553 -> 4.283
#
# [ 2] batch loss: 0.329
# [ 4] batch loss: 0.444
# [ 6] batch loss: 0.405
# [ 8] batch loss: 0.420
# [10] batch loss: 0.392
# epoch 33 loss: 4.299 -> 4.070
# LC loss: 0.015 -> 0.015
# DC loss: 4.283 -> 4.055
#
# [ 2] batch loss: 0.306
# [ 4] batch loss: 0.423
# [ 6] batch loss: 0.382
# [ 8] batch loss: 0.399
# [10] batch loss: 0.372
# epoch 34 loss: 4.070 -> 3.842
# LC loss: 0.015 -> 0.014
# DC loss: 4.055 -> 3.828
#
# [ 2] batch loss: 0.287
# [ 4] batch loss: 0.404
# [ 6] batch loss: 0.360
# [ 8] batch loss: 0.381
# [10] batch loss: 0.355
# epoch 35 loss: 3.842 -> 3.635
# LC loss: 0.014 -> 0.014
# DC loss: 3.828 -> 3.621
#
# [ 2] batch loss: 0.271
# [ 4] batch loss: 0.387
# [ 6] batch loss: 0.342
# [ 8] batch loss: 0.367
# [10] batch loss: 0.339
# epoch 36 loss: 3.635 -> 3.463
# LC loss: 0.014 -> 0.014
# DC loss: 3.621 -> 3.449
#
# [ 2] batch loss: 0.258
# [ 4] batch loss: 0.375
# [ 6] batch loss: 0.326
# [ 8] batch loss: 0.353
# [10] batch loss: 0.325
# epoch 37 loss: 3.463 -> 3.322
# LC loss: 0.014 -> 0.013
# DC loss: 3.449 -> 3.309
#
# [ 2] batch loss: 0.240
# [ 4] batch loss: 0.355
# [ 6] batch loss: 0.315
# [ 8] batch loss: 0.335
# [10] batch loss: 0.311
# epoch 38 loss: 3.322 -> 3.148
# LC loss: 0.013 -> 0.013
# DC loss: 3.309 -> 3.135
#
# [ 2] batch loss: 0.231
# [ 4] batch loss: 0.365
# [ 6] batch loss: 0.289
# [ 8] batch loss: 0.344
# [10] batch loss: 0.313
# epoch 39 loss: 3.148 -> 3.128
# LC loss: 0.013 -> 0.013
# DC loss: 3.135 -> 3.115
#
# [ 2] batch loss: 0.233
# [ 4] batch loss: 0.341
# [ 6] batch loss: 0.342
# [ 8] batch loss: 0.372
# [10] batch loss: 0.296
# epoch 40 loss: 3.128 -> 3.196
# LC loss: 0.013 -> 0.012
# DC loss: 3.115 -> 3.184
# 0.9207547169811321 0.5856606573428748
#
# [ 2] batch loss: 0.346
# [ 4] batch loss: 0.637
# [ 6] batch loss: 0.347
# [ 8] batch loss: 0.681
# [10] batch loss: 0.470
# epoch 41 loss: 3.196 -> 5.407
# LC loss: 0.012 -> 0.012
# DC loss: 3.184 -> 5.395
#
# [ 2] batch loss: 0.320
# [ 4] batch loss: 0.651
# [ 6] batch loss: 1.043
# [ 8] batch loss: 0.645
# [10] batch loss: 0.377
# epoch 42 loss: 5.407 -> 6.443
# LC loss: 0.012 -> 0.012
# DC loss: 5.395 -> 6.431
# [ 2] batch loss: 1.004
# [ 4] batch loss: 1.774
# [ 6] batch loss: 1.018
# [ 8] batch loss: 0.858
# [10] batch loss: 0.477
# epoch 43 loss: 6.443 -> 10.400
# LC loss: 0.012 -> 0.012
# DC loss: 6.431 -> 10.388
#
# [ 2] batch loss: 0.546
# [ 4] batch loss: 0.580
# [ 6] batch loss: 0.493
# [ 8] batch loss: 0.510
# [10] batch loss: 0.497
# epoch 44 loss: 10.400 -> 5.439
# LC loss: 0.012 -> 0.012
# DC loss: 10.388 -> 5.427
#
# [ 2] batch loss: 0.565
# [ 4] batch loss: 0.539
# [ 6] batch loss: 0.483
# [ 8] batch loss: 0.502
# [10] batch loss: 0.452
# epoch 45 loss: 5.439 -> 5.227
# LC loss: 0.012 -> 0.011
# DC loss: 5.427 -> 5.216
#
# [ 2] batch loss: 0.379
# [ 4] batch loss: 0.525
# [ 6] batch loss: 0.462
# [ 8] batch loss: 0.473
# [10] batch loss: 0.421
# epoch 46 loss: 5.227 -> 4.638
# LC loss: 0.011 -> 0.011
# DC loss: 5.216 -> 4.626
#
# [ 2] batch loss: 0.339
# [ 4] batch loss: 0.501
# [ 6] batch loss: 0.427
# [ 8] batch loss: 0.446
# [10] batch loss: 0.399
# epoch 47 loss: 4.638 -> 4.328
# LC loss: 0.011 -> 0.011
# DC loss: 4.626 -> 4.317
#
# [ 2] batch loss: 0.311
# [ 4] batch loss: 0.470
# [ 6] batch loss: 0.403
# [ 8] batch loss: 0.420
# [10] batch loss: 0.372
# epoch 48 loss: 4.328 -> 4.031
# LC loss: 0.011 -> 0.011
# DC loss: 4.317 -> 4.020
#
# [ 2] batch loss: 0.287
# [ 4] batch loss: 0.451
# [ 6] batch loss: 0.381
# [ 8] batch loss: 0.396
# [10] batch loss: 0.348
# epoch 49 loss: 4.031 -> 3.787
# LC loss: 0.011 -> 0.011
# DC loss: 4.020 -> 3.776
#
# [ 2] batch loss: 0.267
# [ 4] batch loss: 0.426
# [ 6] batch loss: 0.357
# [ 8] batch loss: 0.373
# [10] batch loss: 0.330
# epoch 50 loss: 3.787 -> 3.556
# LC loss: 0.011 -> 0.010
# DC loss: 3.776 -> 3.546
# 0.9207547169811321 0.7546359829932638
#
# [ 2] batch loss: 0.250
# [ 4] batch loss: 0.402
# [ 6] batch loss: 0.335
# [ 8] batch loss: 0.353
# [10] batch loss: 0.313
# epoch 51 loss: 3.556 -> 3.346
# LC loss: 0.010 -> 0.010
# DC loss: 3.546 -> 3.335
#
# [ 2] batch loss: 0.232
# [ 4] batch loss: 0.382
# [ 6] batch loss: 0.313
# [ 8] batch loss: 0.335
# [10] batch loss: 0.297
# epoch 52 loss: 3.346 -> 3.154
# LC loss: 0.010 -> 0.010
# DC loss: 3.335 -> 3.144
#
# [ 2] batch loss: 0.218
# [ 4] batch loss: 0.366
# [ 6] batch loss: 0.294
# [ 8] batch loss: 0.319
# [10] batch loss: 0.283
# epoch 53 loss: 3.154 -> 2.988
# LC loss: 0.010 -> 0.010
# DC loss: 3.144 -> 2.978
#
# [ 2] batch loss: 0.205
# [ 4] batch loss: 0.351
# [ 6] batch loss: 0.278
# [ 8] batch loss: 0.305
# [10] batch loss: 0.271
# epoch 54 loss: 2.988 -> 2.841
# LC loss: 0.010 -> 0.010
# DC loss: 2.978 -> 2.831
#
# [ 2] batch loss: 0.193
# [ 4] batch loss: 0.337
# [ 6] batch loss: 0.263
# [ 8] batch loss: 0.292
# [10] batch loss: 0.260
# epoch 55 loss: 2.841 -> 2.710
# LC loss: 0.010 -> 0.010
# DC loss: 2.831 -> 2.700
#
# [ 2] batch loss: 0.183
# [ 4] batch loss: 0.325
# [ 6] batch loss: 0.250
# [ 8] batch loss: 0.280
# [10] batch loss: 0.250
# epoch 56 loss: 2.710 -> 2.592
# LC loss: 0.010 -> 0.010
# DC loss: 2.700 -> 2.582
#
# [ 2] batch loss: 0.174
# [ 4] batch loss: 0.313
# [ 6] batch loss: 0.238
# [ 8] batch loss: 0.269
# [10] batch loss: 0.241
# epoch 57 loss: 2.592 -> 2.485
# LC loss: 0.010 -> 0.010
# DC loss: 2.582 -> 2.475
#
# [ 2] batch loss: 0.166
# [ 4] batch loss: 0.302
# [ 6] batch loss: 0.228
# [ 8] batch loss: 0.258
# [10] batch loss: 0.232
# epoch 58 loss: 2.485 -> 2.386
# LC loss: 0.010 -> 0.009
# DC loss: 2.475 -> 2.376
#
# [ 2] batch loss: 0.159
# [ 4] batch loss: 0.292
# [ 6] batch loss: 0.218
# [ 8] batch loss: 0.248
# [10] batch loss: 0.224
# epoch 59 loss: 2.386 -> 2.293
# LC loss: 0.009 -> 0.009
# DC loss: 2.376 -> 2.284
#
# [ 2] batch loss: 0.152
# [ 4] batch loss: 0.282
# [ 6] batch loss: 0.209
# [ 8] batch loss: 0.238
# [10] batch loss: 0.216
# epoch 60 loss: 2.293 -> 2.206
# LC loss: 0.009 -> 0.009
# DC loss: 2.284 -> 2.197
# 0.9207547169811321 0.8532436394841416
#
# [ 2] batch loss: 0.146
# [ 4] batch loss: 0.273
# [ 6] batch loss: 0.201
# [ 8] batch loss: 0.229
# [10] batch loss: 0.209
# epoch 61 loss: 2.206 -> 2.125
# LC loss: 0.009 -> 0.009
# DC loss: 2.197 -> 2.116
#
# [ 2] batch loss: 0.140
# [ 4] batch loss: 0.265
# [ 6] batch loss: 0.192
# [ 8] batch loss: 0.221
# [10] batch loss: 0.203
# epoch 62 loss: 2.125 -> 2.050
# LC loss: 0.009 -> 0.009
# DC loss: 2.116 -> 2.041
#
# [ 2] batch loss: 0.135
# [ 4] batch loss: 0.257
# [ 6] batch loss: 0.185
# [ 8] batch loss: 0.213
# [10] batch loss: 0.196
# epoch 63 loss: 2.050 -> 1.978
# LC loss: 0.009 -> 0.009
# DC loss: 2.041 -> 1.970
#
# [ 2] batch loss: 0.130
# [ 4] batch loss: 0.250
# [ 6] batch loss: 0.178
# [ 8] batch loss: 0.205
# [10] batch loss: 0.190
# epoch 64 loss: 1.978 -> 1.912
# LC loss: 0.009 -> 0.009
# DC loss: 1.970 -> 1.903
#
# [ 2] batch loss: 0.126
# [ 4] batch loss: 0.243
# [ 6] batch loss: 0.171
# [ 8] batch loss: 0.199
# [10] batch loss: 0.184
# epoch 65 loss: 1.912 -> 1.850
# LC loss: 0.009 -> 0.009
# DC loss: 1.903 -> 1.842
#
# [ 2] batch loss: 0.121
# [ 4] batch loss: 0.236
# [ 6] batch loss: 0.165
# [ 8] batch loss: 0.192
# [10] batch loss: 0.178
# epoch 66 loss: 1.850 -> 1.791
# LC loss: 0.009 -> 0.009
# DC loss: 1.842 -> 1.782
#
# [ 2] batch loss: 0.117
# [ 4] batch loss: 0.229
# [ 6] batch loss: 0.159
# [ 8] batch loss: 0.185
# [10] batch loss: 0.174
# epoch 67 loss: 1.791 -> 1.733
# LC loss: 0.009 -> 0.008
# DC loss: 1.782 -> 1.725
#
# [ 2] batch loss: 0.113
# [ 4] batch loss: 0.225
# [ 6] batch loss: 0.153
# [ 8] batch loss: 0.181
# [10] batch loss: 0.169
# epoch 68 loss: 1.733 -> 1.689
# LC loss: 0.008 -> 0.008
# DC loss: 1.725 -> 1.681
#
# [ 2] batch loss: 0.114
# [ 4] batch loss: 0.224
# [ 6] batch loss: 0.148
# [ 8] batch loss: 0.182
# [10] batch loss: 0.164
# epoch 69 loss: 1.689 -> 1.671
# LC loss: 0.008 -> 0.008
# DC loss: 1.681 -> 1.662
#
# [ 2] batch loss: 0.109
# [ 4] batch loss: 0.213
# [ 6] batch loss: 0.154
# [ 8] batch loss: 0.172
# [10] batch loss: 0.161
# epoch 70 loss: 1.671 -> 1.622
# LC loss: 0.008 -> 0.008
# DC loss: 1.662 -> 1.613
# 0.9220125786163522 0.9307072369557506
#
# [ 2] batch loss: 0.115
# [ 4] batch loss: 0.251
# [ 6] batch loss: 0.141
# [ 8] batch loss: 0.191
# [10] batch loss: 0.179
# epoch 71 loss: 1.622 -> 1.763
# LC loss: 0.008 -> 0.008
# DC loss: 1.613 -> 1.755
#
# [ 2] batch loss: 0.145
# [ 4] batch loss: 0.228
# [ 6] batch loss: 0.194
# [ 8] batch loss: 0.298
# [10] batch loss: 0.161
# epoch 72 loss: 1.763 -> 2.055
# LC loss: 0.008 -> 0.008
# DC loss: 1.755 -> 2.046
#
# [ 2] batch loss: 0.186
# [ 4] batch loss: 0.466
# [ 6] batch loss: 0.231
# [ 8] batch loss: 0.247
# [10] batch loss: 0.274
# epoch 73 loss: 2.055 -> 3.082
# LC loss: 0.008 -> 0.008
# DC loss: 2.046 -> 3.074
#
# [ 2] batch loss: 0.302
# [ 4] batch loss: 0.323
# [ 6] batch loss: 0.774
# [ 8] batch loss: 0.807
# [10] batch loss: 0.443
# epoch 74 loss: 3.082 -> 6.201
# LC loss: 0.008 -> 0.008
# DC loss: 3.074 -> 6.193
#
# [ 2] batch loss: 0.556
# [ 4] batch loss: 1.628
# [ 6] batch loss: 1.537
# [ 8] batch loss: 1.062
# [10] batch loss: 0.387
# epoch 75 loss: 6.201 -> 10.403
# LC loss: 0.008 -> 0.008
# DC loss: 6.193 -> 10.395
#
# [ 2] batch loss: 0.851
# [ 4] batch loss: 1.115
# [ 6] batch loss: 0.322
# [ 8] batch loss: 0.394
# [10] batch loss: 0.270
# epoch 76 loss: 10.403 -> 6.178
# LC loss: 0.008 -> 0.008
# DC loss: 10.395 -> 6.170
#
# [ 2] batch loss: 0.288
# [ 4] batch loss: 0.376
# [ 6] batch loss: 0.327
# [ 8] batch loss: 0.353
# [10] batch loss: 0.275
# epoch 77 loss: 6.178 -> 3.309
# LC loss: 0.008 -> 0.008
# DC loss: 6.170 -> 3.302
#
# [ 2] batch loss: 0.210
# [ 4] batch loss: 0.358
# [ 6] batch loss: 0.282
# [ 8] batch loss: 0.305
# [10] batch loss: 0.282
# epoch 78 loss: 3.309 -> 2.951
# LC loss: 0.008 -> 0.008
# DC loss: 3.302 -> 2.943
#
# [ 2] batch loss: 0.191
# [ 4] batch loss: 0.335
# [ 6] batch loss: 0.259
# [ 8] batch loss: 0.282
# [10] batch loss: 0.235
# epoch 79 loss: 2.951 -> 2.633
# LC loss: 0.008 -> 0.008
# DC loss: 2.943 -> 2.625
#
# [ 2] batch loss: 0.169
# [ 4] batch loss: 0.313
# [ 6] batch loss: 0.234
# [ 8] batch loss: 0.259
# [10] batch loss: 0.218
# epoch 80 loss: 2.633 -> 2.406
# LC loss: 0.008 -> 0.008
# DC loss: 2.625 -> 2.398
# 0.9220125786163522 0.8212825439261191
#
# [ 2] batch loss: 0.159
# [ 4] batch loss: 0.291
# [ 6] batch loss: 0.213
# [ 8] batch loss: 0.239
# [10] batch loss: 0.204
# epoch 81 loss: 2.406 -> 2.227
# LC loss: 0.008 -> 0.007
# DC loss: 2.398 -> 2.219
#
# [ 2] batch loss: 0.145
# [ 4] batch loss: 0.276
# [ 6] batch loss: 0.198
# [ 8] batch loss: 0.223
# [10] batch loss: 0.192
# epoch 82 loss: 2.227 -> 2.081
# LC loss: 0.007 -> 0.007
# DC loss: 2.219 -> 2.073
#
# [ 2] batch loss: 0.136
# [ 4] batch loss: 0.263
# [ 6] batch loss: 0.184
# [ 8] batch loss: 0.209
# [10] batch loss: 0.182
# epoch 83 loss: 2.081 -> 1.956
# LC loss: 0.007 -> 0.007
# DC loss: 2.073 -> 1.949
#
# [ 2] batch loss: 0.127
# [ 4] batch loss: 0.251
# [ 6] batch loss: 0.173
# [ 8] batch loss: 0.196
# [10] batch loss: 0.173
# epoch 84 loss: 1.956 -> 1.850
# LC loss: 0.007 -> 0.007
# DC loss: 1.949 -> 1.842
#
# [ 2] batch loss: 0.120
# [ 4] batch loss: 0.241
# [ 6] batch loss: 0.163
# [ 8] batch loss: 0.185
# [10] batch loss: 0.166
# epoch 85 loss: 1.850 -> 1.755
# LC loss: 0.007 -> 0.007
# DC loss: 1.842 -> 1.747
#
# [ 2] batch loss: 0.113
# [ 4] batch loss: 0.231
# [ 6] batch loss: 0.154
# [ 8] batch loss: 0.175
# [10] batch loss: 0.159
# epoch 86 loss: 1.755 -> 1.670
# LC loss: 0.007 -> 0.007
# DC loss: 1.747 -> 1.663
#
# [ 2] batch loss: 0.108
# [ 4] batch loss: 0.222
# [ 6] batch loss: 0.146
# [ 8] batch loss: 0.166
# [10] batch loss: 0.153
# epoch 87 loss: 1.670 -> 1.595
# LC loss: 0.007 -> 0.007
# DC loss: 1.663 -> 1.588
#
# [ 2] batch loss: 0.102
# [ 4] batch loss: 0.214
# [ 6] batch loss: 0.139
# [ 8] batch loss: 0.158
# [10] batch loss: 0.148
# epoch 88 loss: 1.595 -> 1.527
# LC loss: 0.007 -> 0.007
# DC loss: 1.588 -> 1.520
#
# [ 2] batch loss: 0.098
# [ 4] batch loss: 0.207
# [ 6] batch loss: 0.133
# [ 8] batch loss: 0.151
# [10] batch loss: 0.143
# epoch 89 loss: 1.527 -> 1.467
# LC loss: 0.007 -> 0.007
# DC loss: 1.520 -> 1.460
#
# [ 2] batch loss: 0.094
# [ 4] batch loss: 0.201
# [ 6] batch loss: 0.127
# [ 8] batch loss: 0.145
# [10] batch loss: 0.138
# epoch 90 loss: 1.467 -> 1.414
# LC loss: 0.007 -> 0.007
# DC loss: 1.460 -> 1.407
# 0.9220125786163522 0.900783526822456
#
# [ 2] batch loss: 0.090
# [ 4] batch loss: 0.195
# [ 6] batch loss: 0.122
# [ 8] batch loss: 0.140
# [10] batch loss: 0.134
# epoch 91 loss: 1.414 -> 1.365
# LC loss: 0.007 -> 0.007
# DC loss: 1.407 -> 1.358
#
# [ 2] batch loss: 0.087
# [ 4] batch loss: 0.189
# [ 6] batch loss: 0.117
# [ 8] batch loss: 0.135
# [10] batch loss: 0.130
# epoch 92 loss: 1.365 -> 1.321
# LC loss: 0.007 -> 0.007
# DC loss: 1.358 -> 1.314
#
# [ 2] batch loss: 0.084
# [ 4] batch loss: 0.184
# [ 6] batch loss: 0.113
# [ 8] batch loss: 0.130
# [10] batch loss: 0.126
# epoch 93 loss: 1.321 -> 1.279
# LC loss: 0.007 -> 0.007
# DC loss: 1.314 -> 1.272
#
# [ 2] batch loss: 0.081
# [ 4] batch loss: 0.180
# [ 6] batch loss: 0.109
# [ 8] batch loss: 0.126
# [10] batch loss: 0.123
# epoch 94 loss: 1.279 -> 1.241
# LC loss: 0.007 -> 0.007
# DC loss: 1.272 -> 1.234
#
# [ 2] batch loss: 0.079
# [ 4] batch loss: 0.175
# [ 6] batch loss: 0.105
# [ 8] batch loss: 0.122
# [10] batch loss: 0.120
# epoch 95 loss: 1.241 -> 1.206
# LC loss: 0.007 -> 0.007
# DC loss: 1.234 -> 1.199
#
# [ 2] batch loss: 0.076
# [ 4] batch loss: 0.171
# [ 6] batch loss: 0.102
# [ 8] batch loss: 0.118
# [10] batch loss: 0.117
# epoch 96 loss: 1.206 -> 1.173
# LC loss: 0.007 -> 0.007
# DC loss: 1.199 -> 1.166
#
# [ 2] batch loss: 0.074
# [ 4] batch loss: 0.168
# [ 6] batch loss: 0.099
# [ 8] batch loss: 0.115
# [10] batch loss: 0.114
# epoch 97 loss: 1.173 -> 1.142
# LC loss: 0.007 -> 0.007
# DC loss: 1.166 -> 1.135
#
# [ 2] batch loss: 0.072
# [ 4] batch loss: 0.165
# [ 6] batch loss: 0.096
# [ 8] batch loss: 0.112
# [10] batch loss: 0.111
# epoch 98 loss: 1.142 -> 1.112
# LC loss: 0.007 -> 0.007
# DC loss: 1.135 -> 1.106
#
# [ 2] batch loss: 0.070
# [ 4] batch loss: 0.161
# [ 6] batch loss: 0.093
# [ 8] batch loss: 0.108
# [10] batch loss: 0.108
# epoch 99 loss: 1.112 -> 1.085
# LC loss: 0.007 -> 0.007
# DC loss: 1.106 -> 1.078
#
# [ 2] batch loss: 0.068
# [ 4] batch loss: 0.158
# [ 6] batch loss: 0.090
# [ 8] batch loss: 0.105
# [10] batch loss: 0.106
# epoch 100 loss: 1.085 -> 1.058
# LC loss: 0.007 -> 0.007
# DC loss: 1.078 -> 1.052
# 0.9232704402515723 0.9259361578983331

# %%
#torch.save(cnn_da.state_dict(), "./parameters/cnn_dslr_to_webcam_0.933.pt")

# %%
cnn_da.load_state_dict(torch.load("./parameters/cnn_dslr_to_webcam_0.934.pt"))

# %%
evaluate_da_accuracy(cnn_da, trainloader_webcam, source=False)
# Out:
# (0.9345911949685535, 0.6322475808221589)
